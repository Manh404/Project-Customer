# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
df_customer = pd.read_csv('/content/drive/MyDrive/movie_ticket_data/customer.csv')
df_campaign = pd.read_csv('/content/drive/MyDrive/movie_ticket_data/campaign.csv')
df_device = pd.read_csv('/content/drive/MyDrive/movie_ticket_data/device_detail.csv')
df_status = pd.read_csv('/content/drive/MyDrive/movie_ticket_data/status_detail.csv')
df_ticket = pd.read_csv('/content/drive/MyDrive/movie_ticket_data/ticket_history.csv')

# %% [markdown]
# #2. Data Cleaning

# %% [markdown]
# ##2.1 Data type , NULL values , duplicate values

# %%
df_customer.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 131400 entries, 0 to 131399
# Data columns (total 3 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   customer_id  131400 non-null  int64
#  1   usergender   131400 non-null  object
#  2   dob          131400 non-null  object
# dtypes: int64(1), object(2)
# memory usage: 3.0+ MB

# %%
df_customer.head(2)
# Out:
#    customer_id usergender        dob
# 0       100032     Female   8/8/1985
# 1       100046       Male  7/11/1987

# %%
# Changing data type dob into datetime
from datetime import datetime
df_customer['dob'] = pd.to_datetime(df_customer['dob'])

# %%
df_customer.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 131400 entries, 0 to 131399
# Data columns (total 3 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   customer_id  131400 non-null  int64
#  1   usergender   131400 non-null  object
#  2   dob          131400 non-null  datetime64[ns]
# dtypes: datetime64[ns](1), int64(1), object(1)
# memory usage: 3.0+ MB

# %%
df_customer['customer_id'].nunique()
# Out:
# 131400

# %%
df_campaign.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 216 entries, 0 to 215
# Data columns (total 2 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   campaign_id    216 non-null    int64
#  1   campaign_type  216 non-null    object
# dtypes: int64(1), object(1)
# memory usage: 3.5+ KB

# %%
df_campaign.head(2)
# Out:
#    campaign_id    campaign_type
# 0       106460  direct discount
# 1        30040  direct discount

# %%
df_campaign.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 216 entries, 0 to 215
# Data columns (total 2 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   campaign_id    216 non-null    int64
#  1   campaign_type  216 non-null    object
# dtypes: int64(1), object(1)
# memory usage: 3.5+ KB

# %%
df_campaign['campaign_id'].nunique()
# Out:
# 216

# %%
df_device.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 139902 entries, 0 to 139901
# Data columns (total 3 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   device_number  139901 non-null  object
#  1   model          132763 non-null  object
#  2   platform       139902 non-null  object
# dtypes: object(3)
# memory usage: 3.2+ MB

# %%
# create func calculate NULL rate of each column

def calc_null_rate(df):
    newdf = df.isnull().sum().to_frame('null_count')
    newdf[['null_rate']] = newdf[['null_count']] / len(df)
    return newdf.sort_values(by='null_rate', ascending=False)

# %%
calc_null_rate(df_device)
# Out:
#                null_count  null_rate
# model                7139   0.051029
# device_number           1   0.000007
# platform                0   0.000000

# %%
# Replace NULL in model into "unknown"
# Delete NULL in device_number

df_device = df_device.fillna({'model':'unknown'})
df_device = df_device[df_device['device_number'].notna()]

# %%
calc_null_rate(df_device)
# Out:
#                null_count  null_rate
# device_number           0        0.0
# model                   0        0.0
# platform                0        0.0

# %%
# Status board
df_status.head(10)
# Out:
#    status_id                                        description error_group
# 0          1                                   Order successful         NaN
# 1         -1                                    Payment overdue    customer
# 2         -2  Insufficient funds in customer account. Please...    customer
# 3         -3                         No response from your bank    external
# 4         -4  Password locked due to multiple incorrect atte...    customer
# 5         -5                           Payment failed from bank    external
# 6         -6               Need verify your account to continue    customer
# 7         -7                    Transaction temporarily limited    internal

# %%
# Ticket Board

df_ticket.head(10)
# Out:
#                           ticket_id  customer_id paying_method  theater_name  \
# 0  4f5200dcdcf2396b8d50ff84bf423f32       100009  money in app          13.0
# 1  07abbaf28c772692f0367ad992bb3184       100493  bank account         180.0
# 2  1fdbeb7eceba8a27d9d985b5b70c219a       100596  money in app          56.0
# 3  7715c9955866bd296b98543412839abd       100852  bank account         119.0
# 4  776efd7bda0b715084430e6385f67746       100965  money in app         107.0
# 5  284d3fe54b25bb1877106b3335b82333       101001  money in app         125.0
# 6  4dd5ea254588f1f287c6c2753286c719       101001  bank account         125.0
# 7  63e2018e8d2a277b31c37094d3325ccd       101502    debit card          84.0
# 8  e3a7ee66aa7633c807af92fd60938d2a       101788  money in app          22.0
# 9  bac5700d10216de03474a15d415c63f7       101905  bank account          82.0
#
#                       device_number  original_price  discount_value  \
# 0  244764a57dbdeb8fe9b164847ad55183            9.90            2.10
# 1  8fa83cf46284aafd6e5da6c96f7862b5            8.66            1.48
# 2  69cf9244654949047f006e441fa7a8a7           10.31            2.31
# 3  879ed11af9d6d2b5cda4d299590735a7           27.75            1.03
# 4  0a233600d993a02cc1d39fb0d87fc7de            4.33            1.03
# 5  5aabc65644be6e7cd4af5fcf21dfc561            5.16            2.31
# 6  74885e0163f3c8f3d78a8fb31f9aabef            5.16            2.31
# 7  c8efd306a2523f6abb4a890a32e68ec3            5.16            2.31
# 8  d4e7cfd6fb199d3fa6b94ce3a84da1c5            4.74            1.90
# 9  cd8d12a270b291287a8e77f292b6006d           10.31            2.31
#
#    final_price                     time  status_id  campaign_id  \
# 0         7.80  2022-07-08 17:46:36.145          1        83330
# 1         7.18  2022-07-15 20:44:09.952          1        83330
# 2         8.00  2022-07-30 11:16:55.483          1            0
# 3        26.72  2022-07-04 22:33:07.458          1        85940
# 4         3.30  2022-07-03 18:41:45.098          1        85940
# 5         2.85  2022-07-08 13:44:11.611          1        83330
# 6         2.85  2022-07-08 13:23:28.482         -5        83330
# 7         2.85  2022-07-17 17:41:47.684          1        83330
# 8         2.84  2022-07-06 20:54:39.705          1        83330
# 9         8.00  2022-07-09 10:59:58.494          1        83330
#
#                movie_name
# 0  Thor: Love And Thunder
# 1  Thor: Love And Thunder
# 2  Thor: Love And Thunder
# 3  Thor: Love And Thunder
# 4  Thor: Love And Thunder
# 5  Thor: Love And Thunder
# 6  Thor: Love And Thunder
# 7  Thor: Love And Thunder
# 8  Thor: Love And Thunder
# 9  Thor: Love And Thunder

# %%
df_ticket.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 154827 entries, 0 to 154826
# Data columns (total 12 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   ticket_id       154827 non-null  object
#  1   customer_id     154827 non-null  int64
#  2   paying_method   154827 non-null  object
#  3   theater_name    154827 non-null  float64
#  4   device_number   154827 non-null  object
#  5   original_price  154827 non-null  float64
#  6   discount_value  154827 non-null  float64
#  7   final_price     154827 non-null  float64
#  8   time            154827 non-null  object
#  9   status_id       154827 non-null  int64
#  10  campaign_id     154827 non-null  int64
#  11  movie_name      154827 non-null  object
# dtypes: float64(4), int64(3), object(5)
# memory usage: 14.2+ MB

# %%
# Changing data type of TIME

# %%
df_ticket['time'] = pd.to_datetime(df_ticket['time'])

# %%
calc_null_rate(df_ticket)
# Out:
#                 null_count  null_rate
# ticket_id                0        0.0
# customer_id              0        0.0
# paying_method            0        0.0
# theater_name             0        0.0
# device_number            0        0.0
# original_price           0        0.0
# discount_value           0        0.0
# final_price              0        0.0
# time                     0        0.0
# status_id                0        0.0
# campaign_id              0        0.0
# movie_name               0        0.0

# %%
df_ticket['ticket_id'].nunique()
# Out:
# 154725

# %%
df_dup = df_ticket[df_ticket.duplicated(keep = False)]

# %%
df_dup.head(10)
# Out:
#                               ticket_id  customer_id paying_method  \
# 3555   c56e3eb9fb1fd241c9de7a700d7a52d2       206709  money in app
# 3556   c56e3eb9fb1fd241c9de7a700d7a52d2       206709  money in app
# 49730  763e20c9c1136c5c06d9a960fac9dae6       174180   credit card
# 49731  763e20c9c1136c5c06d9a960fac9dae6       174180   credit card
# 49876  257d0a0e6a7f38b90b5ecdfa9e8416b9       133912  money in app
# 49877  257d0a0e6a7f38b90b5ecdfa9e8416b9       133912  money in app
# 50202  6dec59a668243f07301d5bf3c2368fa0       111474    debit card
# 50203  6dec59a668243f07301d5bf3c2368fa0       111474    debit card
# 50212  5f377be63fca730d5b5d12e06ac3f05d       117355   credit card
# 50213  5f377be63fca730d5b5d12e06ac3f05d       117355   credit card
#
#        theater_name                     device_number  original_price  \
# 3555            5.0  291f6a5c77b7d98a86fe76bdbabe94eb            5.77
# 3556            5.0  291f6a5c77b7d98a86fe76bdbabe94eb            5.77
# 49730          29.0  ba5794fca2cba47fd0141dd3fb195934            7.42
# 49731          29.0  ba5794fca2cba47fd0141dd3fb195934            7.42
# 49876         119.0  18abc497c03f7e6bd0b0cf72a89fb911            7.42
# 49877         119.0  18abc497c03f7e6bd0b0cf72a89fb911            7.42
# 50202         109.0  a07a8e335cc40b1e39e2d7fc9a9af557            8.66
# 50203         109.0  a07a8e335cc40b1e39e2d7fc9a9af557            8.66
# 50212          53.0  9092a5b635cbcf89633ff48766bc04e6            7.84
# 50213          53.0  9092a5b635cbcf89633ff48766bc04e6            7.84
#
#        discount_value  final_price                    time  status_id  \
# 3555             1.03         4.74 2022-07-02 22:11:30.005          1
# 3556             1.03         4.74 2022-07-02 22:11:30.005          1
# 49730            0.00         7.42 2019-12-23 15:28:45.738          1
# 49731            0.00         7.42 2019-12-23 15:28:45.738          1
# 49876            0.00         7.42 2019-12-23 18:04:51.790          1
# 49877            0.00         7.42 2019-12-23 18:04:51.790          1
# 50202            0.00         8.66 2019-12-23 10:35:45.542          1
# 50203            0.00         8.66 2019-12-23 10:35:45.542          1
# 50212            0.00         7.84 2019-12-23 19:30:23.767          1
# 50213            0.00         7.84 2019-12-23 19:30:23.767          1
#
#        campaign_id              movie_name
# 3555         85940  Thor: Love And Thunder
# 3556         85940  Thor: Love And Thunder
# 49730            0             Dreamy Eyes
# 49731            0             Dreamy Eyes
# 49876            0             Dreamy Eyes
# 49877            0             Dreamy Eyes
# 50202            0             Dreamy Eyes
# 50203            0             Dreamy Eyes
# 50212            0             Dreamy Eyes
# 50213            0             Dreamy Eyes

# %%
df_ticket.drop_duplicates(inplace=True)

# %%
df_ticket['ticket_id'].nunique()
# Out:
# 154725

# %%
df_ticket.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 154725 entries, 0 to 154826
# Data columns (total 12 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   ticket_id       154725 non-null  object
#  1   customer_id     154725 non-null  int64
#  2   paying_method   154725 non-null  object
#  3   theater_name    154725 non-null  float64
#  4   device_number   154725 non-null  object
#  5   original_price  154725 non-null  float64
#  6   discount_value  154725 non-null  float64
#  7   final_price     154725 non-null  float64
#  8   time            154725 non-null  datetime64[ns]
#  9   status_id       154725 non-null  int64
#  10  campaign_id     154725 non-null  int64
#  11  movie_name      154725 non-null  object
# dtypes: datetime64[ns](1), float64(4), int64(3), object(4)
# memory usage: 15.3+ MB

# %% [markdown]
# ## 2.2 Join Tables

# %%
df_join_customer = pd.merge( df_ticket, df_customer, how='left', on='customer_id')
df_join_campaign = pd.merge( df_join_customer, df_campaign, how='left', on='campaign_id')
df_join_status = pd.merge( df_join_campaign, df_status, how='left', on='status_id')
df_join_all = pd.merge( df_join_status, df_device, how='left', on='device_number')

# %%
df_join_all.head(2)
# Out:
#                           ticket_id  customer_id paying_method  theater_name  \
# 0  4f5200dcdcf2396b8d50ff84bf423f32       100009  money in app          13.0
# 1  07abbaf28c772692f0367ad992bb3184       100493  bank account         180.0
#
#                       device_number  original_price  discount_value  \
# 0  244764a57dbdeb8fe9b164847ad55183            9.90            2.10
# 1  8fa83cf46284aafd6e5da6c96f7862b5            8.66            1.48
#
#    final_price                    time  status_id  campaign_id  \
# 0         7.80 2022-07-08 17:46:36.145          1        83330
# 1         7.18 2022-07-15 20:44:09.952          1        83330
#
#                movie_name usergender        dob    campaign_type  \
# 0  Thor: Love And Thunder       Male 1989-02-25  direct discount
# 1  Thor: Love And Thunder       Male 1991-06-09  direct discount
#
#         description error_group       model platform
# 0  Order successful         NaN  iPhone13,1   mobile
# 1  Order successful         NaN     browser  website

# %%
calc_null_rate(df_join_all)
# Out:
#                 null_count  null_rate
# error_group         133679   0.863978
# campaign_type        63098   0.407807
# platform                78   0.000504
# model                   78   0.000504
# paying_method            0   0.000000
# ticket_id                0   0.000000
# customer_id              0   0.000000
# theater_name             0   0.000000
# device_number            0   0.000000
# original_price           0   0.000000
# discount_value           0   0.000000
# campaign_id              0   0.000000
# status_id                0   0.000000
# time                     0   0.000000
# final_price              0   0.000000
# dob                      0   0.000000
# usergender               0   0.000000
# movie_name               0   0.000000
# description              0   0.000000

# %%
df_join_all = df_join_all.fillna('unknown')

# %%
calc_null_rate(df_join_all)
# Out:
#                 null_count  null_rate
# ticket_id                0        0.0
# customer_id              0        0.0
# paying_method            0        0.0
# theater_name             0        0.0
# device_number            0        0.0
# original_price           0        0.0
# discount_value           0        0.0
# final_price              0        0.0
# time                     0        0.0
# status_id                0        0.0
# campaign_id              0        0.0
# movie_name               0        0.0
# usergender               0        0.0
# dob                      0        0.0
# campaign_type            0        0.0
# description              0        0.0
# error_group              0        0.0
# model                    0        0.0
# platform                 0        0.0

# %% [markdown]
# ## 2.3 View all values of each columns

# %%
df_join_all.nunique().sort_values(ascending=False)
# Out:
# ticket_id         154725
# time              154725
# device_number     126459
# customer_id       119477
# dob                11322
# final_price         2715
# original_price      1895
# model               1215
# movie_name           253
# discount_value       242
# campaign_id          211
# theater_name         179
# status_id              8
# description            8
# paying_method          5
# error_group            4
# campaign_type          4
# usergender             3
# platform               3
# dtype: int64

# %%
specific_cols= ['movie_name', 'description', 'paying_method','campaign_type', 'usergender', 'platform', 'error_group']
for col in specific_cols:
    print(col + ' :', np.sort(df_join_all[col].unique().astype(str)))
    print('r')
    print('--------------------')
    print('\r')
# Out:
# movie_name : ['13rd Sister' '13rd Sister: Three Deadly Days' '1990' '2037'
#  '30 Chua Phai Tet' '47 Meters Down: Uncaged' 'A Chamada Da Selva'
#  'A Diamond In The Rough' 'Accidentally Dad' 'Aladdin' 'Alienoid'
#  'Alita: Battle Angel' 'Ambulance' 'Anchor' 'Angel Has Fallen' 'Anna'
#  'Annabelle Comes Home' 'Aquaman' 'Around The World In 80 Days'
#  'Autumn Promise' 'Avatar' 'Avatar: The Way Of Water' 'Avengers: Endgame'
#  'Bad Boys For Life' 'Batman' 'Beast' 'Birds Of Prey' 'Black Adam'
#  'Black Panther 2: Wakanda Forever' 'Black Panther: Wakanda Forever'
#  'Blood Karma' 'Blood Moon Party' 'Bloodshot' 'Broker' 'Bullet Train'
#  'Bumblebee' 'Bắc Kim Thang' 'Camellia Sisters' 'Captain Marvel'
#  "Charlie's Angels" 'Cherry Magic The Movie Thirty Years'
#  'Chickenhare And The Hamster Of Darkness' 'Chuyện Ma Đô Thị' 'Collectors'
#  'Concessions' 'Confidential Assignment 2: International' 'Cracked'
#  'Crawl' 'Crazy Romance' "Dad I'm Sorry" 'Daddy Issues' 'Daeng'
#  'Dark Figure Of Crime' 'Dc League Of Super-Pets' 'Dear Devil Brother'
#  'Death On The Nile' 'Decibel' 'Decision To Leave'
#  'Demon Slayer: Kimetsu No Yaiba'
#  'Detective Conan: The Bride Of Halloween'
#  'Detective Conan: The Fist Of Blue Sapphire'
#  'Detective Conan: The Scarlet Bullet' 'Doctor Sleep'
#  'Doctor Strange In The Multiverse Of Madness' 'Dolittle'
#  "Doraemon: Nobita's Chronicle Of The Moon"
#  "Doraemon: Nobita's Little Star Wars 2021"
#  "Doraemon: Nobita's New Dinosaur" 'Dragon Ball Super: Super Hero'
#  'Dreamy Eyes' 'Em La Cua Em' 'Emergency Declaration' 'Encanto'
#  'Escape Room' 'Eternals' 'Everest' 'Everything Everywhere All At Once'
#  'Exit' 'Extreme Job' 'Extremely Easy Job' 'Face Off: 48h'
#  'Fantastic Beasts: Secrets Of Dumbledore'
#  'Fantastic Beasts: The Secrets Of Dumbledore'
#  'Fast & Furious Presents: Hobbs & Shaw' 'Fast Film' 'Friend Zone'
#  'Frozen 2' 'Frozen Ii' 'Furie' 'Furies' 'Gemini Man' 'Girl From The Past'
#  'Glass' 'Glorious Ashes' 'Godzilla Vs. Kong'
#  'Godzilla: King Of The Monsters' 'Goodbye Mother' 'Greenland'
#  'Harry Potter' 'Harry Potter And The Chamber Of Secrets'
#  'Harry Potter And The Deathly Hallows'
#  'Harry Potter And The Goblet Of Fire'
#  "Harry Potter And The Philosopher's Stone"
#  'Harry Potter And The Prisoner Of Azkaban' 'Hellboy' 'Hitman: Agent Jun'
#  'Honest Thief' 'House Of Gucci' 'How To Train Your Dragon'
#  'Inseparable Bros' 'It Chapter Two' 'Ivanna' 'Jailangkung: Sandekala'
#  'John Wick 3: Parabellum' 'John Wick: Chapter 3 – Parabellum' 'Joker'
#  'Jujutsu Kaisen 0' 'Jumanji' 'Jun-45' 'Jurassic World Dominion'
#  'Key Of Life Vietnam' 'Kisaragi Station' 'Knives Out' 'Kumanthong'
#  'Lat Mat 4: Nha Co Khach' 'Lightyear' 'Lost In Mekong Delta'
#  'Love Battle' 'Love Destiny' 'Love Destiny: The Movie'
#  'Lyle Lyle Crocodile' 'Maika' 'Maleficent' 'Maleficent: Mistress Of Evil'
#  'Men Gai Mien Tay' 'Men In Black: International'
#  'Minions: The Rise Of Gru' 'Miss Gangster' 'Moonfall' 'Morbius'
#  'Mortal Kombat' 'Muoi: The Curse Returns' 'My Father Is A Playboy'
#  'My Female Partner' 'My Girl' 'Naked Truth'
#  'Nct Dream The Movie : In A Dream' 'Ne Zha' 'Ngoi Nha Buom Buom'
#  'No Time To Die' 'Nope' 'Once Upon A Time... In Hollywood'
#  'One Piece Film: Red' 'One Piece: Stampede' 'P Storm' 'Parasite' 'Pawn'
#  'Paws Of Fury: The Legend Of Hank' 'Peninsula'
#  'Pháp Sư Mù: Ai Chết Giơ Tay' 'Pil' 'Playing With Fire'
#  'Pokémon Detective Pikachu' 'Pokémon: Detective Pikachu'
#  'Prey For The Devil' 'Puss In Boots: The Last Wish'
#  'Raya And The Last Dragon' 'Rom' 'Romang' "Satan's Slaves 2"
#  'Scary Stories To Tell In The Dark' 'Secret Zoo' 'Semantic Error'
#  'Seo Bok' 'Shang Chi' 'Shark Bait' 'Shazam!' 'Shutter Island' 'Sing 2'
#  'Sister Sister' 'Smile' 'Soul' 'Spider' 'Spider-Man Far From Home'
#  'Spider-Man: No Way Home' 'Spies In Disguise'
#  'Star Wars: The Rise Of Skywalker' 'Starium' 'Superstar Teacher'
#  'Tazza: One Eyed Jack' 'Tenet' 'Terminator: Dark Fate'
#  'The Addams Family' 'The Ancestral' 'The Angry Birds Movie 2'
#  'The Bad Guys' 'The Bad Guys: Reign Of Chaos' 'The Batman'
#  'The Black Phone' 'The Brilliant Darkness!' 'The Con-Heartist'
#  'The Croods: A New Age' 'The Curse Of La Llorona' 'The Divine Fury'
#  'The Drama Queen' 'The Eyes' 'The Father'
#  'The Ghoul: Horror At The Howling Field' 'The Golden Holiday'
#  'The Guardian' 'The Hustle' 'The Instrument Of Murder'
#  'The Invisible Man' 'The Invitation' 'The Lion King'
#  'The Lord Of The Rings' 'The Lost City' 'The Medium' 'The Menu'
#  'The New King Of Comedy' 'The Nightmares' 'The Perfect Wedding'
#  "The Queen's Corgi" 'The Royal Bride' 'The Secret Life Of Pets 2'
#  'The Third Wife' 'The White Storm 2: Drug Lords'
#  'The Witch: Part 2. The Other One' 'The Witcher'
#  'This House Is Not For Sal' 'Thor: Love And Thunder' 'Ticket To Paradise'
#  'Tom' 'Top Gun: Maverick' 'Toy Story 4' 'Truyên Ngan' 'Trạng Quỳnh'
#  'Trạng Tí' 'Turning Red' 'Underwater' 'Us' 'Venom: Let There Be Carnage'
#  'Vietnamese Horror Story' 'Violent Night' 'Weathering With You'
#  'Where The Crawdads Sing' 'Win My Baby Back' 'Wonder Woman 1984'
#  'Wrath Of Man' 'X' 'You And Trinh' 'Zhu Xian' 'Zombieland: Double Tap']
# r
# --------------------
#
# description : ['Insufficient funds in customer account. Please add more funds and try the transaction again.'
#  'Need verify your account to continue' 'No response from your bank'
#  'Order successful'
#  'Password locked due to multiple incorrect attempts. Choose Forgot Password to unlock.'
#  'Payment failed from bank' 'Payment overdue'
#  'Transaction temporarily limited']
# r
# --------------------
#
# paying_method : ['bank account' 'credit card' 'debit card' 'money in app' 'other']
# r
# --------------------
#
# campaign_type : ['direct discount' 'reward point' 'unknown' 'voucher']
# r
# --------------------
#
# usergender : ['Female' 'Male' 'Not verify']
# r
# --------------------
#
# platform : ['mobile' 'unknown' 'website']
# r
# --------------------
#
# error_group : ['customer' 'external' 'internal' 'unknown']
# r
# --------------------

# %% [markdown]
# ##3 Analyst

# %% [markdown]
# ## 3.1 customer portrait

# %% [markdown]
# Age and gender distribution

# %%
df_join_all.head(2)
# Out:
#                           ticket_id  customer_id paying_method  theater_name  \
# 0  4f5200dcdcf2396b8d50ff84bf423f32       100009  money in app          13.0
# 1  07abbaf28c772692f0367ad992bb3184       100493  bank account         180.0
#
#                       device_number  original_price  discount_value  \
# 0  244764a57dbdeb8fe9b164847ad55183            9.90            2.10
# 1  8fa83cf46284aafd6e5da6c96f7862b5            8.66            1.48
#
#    final_price                    time  status_id  campaign_id  \
# 0         7.80 2022-07-08 17:46:36.145          1        83330
# 1         7.18 2022-07-15 20:44:09.952          1        83330
#
#                movie_name usergender        dob    campaign_type  \
# 0  Thor: Love And Thunder       Male 1989-02-25  direct discount
# 1  Thor: Love And Thunder       Male 1991-06-09  direct discount
#
#         description error_group       model platform
# 0  Order successful     unknown  iPhone13,1   mobile
# 1  Order successful     unknown     browser  website

# %%
current_date = datetime.now()


df_join_all['age_days'] = (current_date - df_join_all['dob']).dt.days
df_join_all['age'] = df_join_all['age_days'] / 365.25
df_join_all['age'] = df_join_all['age'] .astype(int)

# %%
current_date
# Out:
# datetime.datetime(2025, 5, 10, 12, 32, 12, 89842)

# %%
# KH age and gender
df_cus = df_join_all.drop_duplicates(subset=['customer_id'])[['customer_id','age','dob', 'usergender']]
df_cus.head(2)
# Out:
#    customer_id  age        dob usergender
# 0       100009   36 1989-02-25       Male
# 1       100493   33 1991-06-09       Male

# %%
plt.figure(figsize=(8,4))
df_cus['age'].hist(bins = 30 , color = 'cornflowerblue', grid=False )
plt.xlabel('ages')
plt.ylabel('#customers')
plt.title('Age distribution')
plt.show()

# %%
## Histogram gender :

plt.figure(figsize=(8,4))

## data
male_age = df_cus[df_cus['usergender'] == 'Male']['age']
female_age = df_cus[df_cus['usergender'] == 'Female']['age']
unknown_age = df_cus[df_cus['usergender'] == 'Not verify']['age']

## plot
plt.hist(male_age, bins = 30 , alpha = 0.3 , color = 'cornflowerblue' , label = 'Male')
plt.hist(female_age, bins = 30, alpha = 0.3 , color = 'salmon', label = 'Female')
plt.hist(unknown_age , bins = 30, alpha = 0.3, color = 'limegreen', label = 'Not verify')

##edit
plt.title('Age distribution')
plt.xlabel('ages')
plt.ylabel('#customers')
plt.legend()
plt.show()

# %%
#Đánh giá Notverify
df_gen = df_cus.groupby('usergender').agg(total = ('customer_id', 'count')).sort_values(by='total', ascending=False).reset_index()
df_gen
# Out:
#    usergender  total
# 0      Female  55689
# 1        Male  50873
# 2  Not verify  12915

# %%
# Visualize

plt.pie(df_gen['total'], labels= df_gen['usergender'], colors=['cornflowerblue', 'lightblue', 'slategrey'], autopct= '%1.1f%%', startangle=90)
plt.show()

# %% [markdown]
# ## Age generation distributon

# %%
df_cus.head(2)
# Out:
#    customer_id  age        dob usergender
# 0       100009   36 1989-02-25       Male
# 1       100493   33 1991-06-09       Male

# %%
#Logic phân loại X, Y , Z Baby boomers

df_cus['age_generation'] = df_cus['dob'].apply(lambda x: 'baby boomers' if x.year < 1965 else 'gen X' if x.year < 1981 else ' gen Y' if x.year < 1997 else 'gen Z')

# %%
df_gen_group = df_cus[df_cus['usergender'] != 'Not verify'] \
             .groupby('age_generation') \
             .agg(total = ('customer_id', 'count')) \
             .sort_values(by='total', ascending=False) \
             .reset_index()

# %%
df_gen_group
# Out:
#   age_generation  total
# 0          gen Y  63310
# 1          gen Z  38401
# 2          gen X   4261
# 3   baby boomers    590

# %%
# Combine 2 diagram
plt.figure(figsize=(13,4))

# plot 1
ax1 = plt.subplot(1,2,1)
df_cus[df_cus['usergender'] != 'Not verify']['age'].hist(bins = 30 , color = 'cornflowerblue', grid=False )
plt.xlabel('ages')
plt.ylabel('#customers')
plt.title('Age distribution')

# plot 2
ax2 = plt.subplot(1,2,2)
plt.pie(df_gen_group['total'], labels= df_gen_group['age_generation'], colors=['cornflowerblue', 'lightblue', 'slategrey', 'lightskyblue'], autopct= '%1.1f%%', startangle=90)
plt.show()

# %% [markdown]
# ##3.2 Time series data - When did customers buy tickets ?

# %%
df_join_all.head(2)
# Out:
#                           ticket_id  customer_id paying_method  theater_name  \
# 0  4f5200dcdcf2396b8d50ff84bf423f32       100009  money in app          13.0
# 1  07abbaf28c772692f0367ad992bb3184       100493  bank account         180.0
#
#                       device_number  original_price  discount_value  \
# 0  244764a57dbdeb8fe9b164847ad55183            9.90            2.10
# 1  8fa83cf46284aafd6e5da6c96f7862b5            8.66            1.48
#
#    final_price                    time  status_id  campaign_id  \
# 0         7.80 2022-07-08 17:46:36.145          1        83330
# 1         7.18 2022-07-15 20:44:09.952          1        83330
#
#                movie_name usergender        dob    campaign_type  \
# 0  Thor: Love And Thunder       Male 1989-02-25  direct discount
# 1  Thor: Love And Thunder       Male 1991-06-09  direct discount
#
#         description error_group       model platform  age_days  age
# 0  Order successful     unknown  iPhone13,1   mobile     13223   36
# 1  Order successful     unknown     browser  website     12389   33

# %%
df_join_all['time'] = pd.to_datetime(df_join_all['time'])
df_join_all['month'] = pd.to_datetime(df_join_all['time']).dt.month
df_join_all['name_day'] = pd.to_datetime(df_join_all['time']).dt.day_name()
df_join_all['hour'] = pd.to_datetime(df_join_all['time']).dt.hour
df_join_all['year_month'] = df_join_all['time'].dt.strftime('%Y-%m')

# %%
#Thống kê theo tháng
df_time_month = (
    df_join_all
    .groupby('year_month')
    .agg(total_ticket = ('ticket_id', 'count'))
    .reset_index()
)

# %%
df_time_month.head(10)
# Out:
#   year_month  total_ticket
# 0    2019-01          2019
# 1    2019-02          1626
# 2    2019-03          1004
# 3    2019-04          4069
# 4    2019-05          4430
# 5    2019-06          4387
# 6    2019-07          3872
# 7    2019-08          5444
# 8    2019-09          3278
# 9    2019-10          5284

# %%
# Histogram of month
plt.figure(figsize=(13,4))

plt.fill_between(df_time_month['year_month'], df_time_month['total_ticket'], color = 'cornflowerblue', alpha = 0.7)
plt.title('#Ticket by months')
plt.xticks(rotation=90)
plt.show()

# %%
## During covid , people do not go watching movies
# Need a DIM time with month (FULL)

# %%
## create DIM time to join data ticket

# %%
start_date = '2019-01-01'
end_date = '2022-12-31'

date_range = pd.date_range(start=start_date, end=end_date, freq='MS')

list_month = date_range.month
list_month_name = date_range.strftime('%B')
list_year = date_range.year
list_year_month = date_range.strftime('%Y-%m')

dim_time = pd.DataFrame( {
    'month_number': list_month,
    'month_name': list_month_name,
    'year': list_year,
    'year_month': list_year_month
}
)

# %%
dim_time
# Out:
#     month_number month_name  year year_month
# 0              1    January  2019    2019-01
# 1              2   February  2019    2019-02
# 2              3      March  2019    2019-03
# 3              4      April  2019    2019-04
# 4              5        May  2019    2019-05
# 5              6       June  2019    2019-06
# 6              7       July  2019    2019-07
# 7              8     August  2019    2019-08
# 8              9  September  2019    2019-09
# 9             10    October  2019    2019-10
# 10            11   November  2019    2019-11
# 11            12   December  2019    2019-12
# 12             1    January  2020    2020-01
# 13             2   February  2020    2020-02
# 14             3      March  2020    2020-03
# 15             4      April  2020    2020-04
# 16             5        May  2020    2020-05
# 17             6       June  2020    2020-06
# 18             7       July  2020    2020-07
# 19             8     August  2020    2020-08
# 20             9  September  2020    2020-09
# 21            10    October  2020    2020-10
# 22            11   November  2020    2020-11
# 23            12   December  2020    2020-12
# 24             1    January  2021    2021-01
# 25             2   February  2021    2021-02
# 26             3      March  2021    2021-03
# 27             4      April  2021    2021-04
# 28             5        May  2021    2021-05
# 29             6       June  2021    2021-06
# 30             7       July  2021    2021-07
# 31             8     August  2021    2021-08
# 32             9  September  2021    2021-09
# 33            10    October  2021    2021-10
# 34            11   November  2021    2021-11
# 35            12   December  2021    2021-12
# 36             1    January  2022    2022-01
# 37             2   February  2022    2022-02
# 38             3      March  2022    2022-03
# 39             4      April  2022    2022-04
# 40             5        May  2022    2022-05
# 41             6       June  2022    2022-06
# 42             7       July  2022    2022-07
# 43             8     August  2022    2022-08
# 44             9  September  2022    2022-09
# 45            10    October  2022    2022-10
# 46            11   November  2022    2022-11
# 47            12   December  2022    2022-12

# %%
#JOIN with df_join_all to have full data of time

df_time_month_dim = (
    pd.merge(dim_time, df_join_all, how='left', on='year_month')
    .groupby('year_month')
    .agg(total_ticket = ('ticket_id', 'count'))
    .reset_index()
)

# %%
df_time_month_dim.replace(0, np.nan, inplace=True)

# %%
df_time_month_dim
# Out:
#    year_month  total_ticket
# 0     2019-01        2019.0
# 1     2019-02        1626.0
# 2     2019-03        1004.0
# 3     2019-04        4069.0
# 4     2019-05        4430.0
# 5     2019-06        4387.0
# 6     2019-07        3872.0
# 7     2019-08        5444.0
# 8     2019-09        3278.0
# 9     2019-10        5284.0
# 10    2019-11        2722.0
# 11    2019-12        1651.0
# 12    2020-01        1289.0
# 13    2020-02        1092.0
# 14    2020-03         319.0
# 15    2020-04           NaN
# 16    2020-05          49.0
# 17    2020-06           2.0
# 18    2020-07         229.0
# 19    2020-08         142.0
# 20    2020-09         619.0
# 21    2020-10        1488.0
# 22    2020-11         932.0
# 23    2020-12        2124.0
# 24    2021-01        1137.0
# 25    2021-02         237.0
# 26    2021-03        6127.0
# 27    2021-04        2690.0
# 28    2021-05         239.0
# 29    2021-06           9.0
# 30    2021-07          10.0
# 31    2021-08           NaN
# 32    2021-09           NaN
# 33    2021-10          10.0
# 34    2021-11          94.0
# 35    2021-12        1367.0
# 36    2022-01         564.0
# 37    2022-02        4206.0
# 38    2022-03        4713.0
# 39    2022-04        5403.0
# 40    2022-05       13209.0
# 41    2022-06        8640.0
# 42    2022-07       17740.0
# 43    2022-08        5531.0
# 44    2022-09        7864.0
# 45    2022-10        9810.0
# 46    2022-11        8280.0
# 47    2022-12        8774.0

# %%
plt.figure(figsize=(13,4))

plt.fill_between(df_time_month_dim['year_month'], df_time_month_dim['total_ticket'], color = 'cornflowerblue', alpha = 0.7)
plt.title('#Ticket by months')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# ##Trend by week days

# %%
df_week_day= (
    df_join_all
    .groupby('name_day')
    .agg(total_ticket = ('ticket_id', 'count'))
    .reset_index()
)

# %%
plt.figure(figsize=(13,4))

plt.fill_between(df_week_day['name_day'], df_week_day['total_ticket'], color = 'cornflowerblue', alpha = 0.7)
plt.title('#Ticket by week day')
plt.xticks(rotation=90)
plt.show()

# %%
# Sorting day in weeks
week_order = ['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday']
df_week_day['day_order'] = pd.Categorical(df_week_day['name_day'], categories=week_order, ordered=True)
df_week_day.sort_values('day_order', inplace=True)

# %%
df_week_day
# Out:
#     name_day  total_ticket  day_order
# 1     Monday         16702     Monday
# 5    Tuesday         14793    Tuesday
# 6  Wednesday         16281  Wednesday
# 4   Thursday         19101   Thursday
# 0     Friday         26438     Friday
# 2   Saturday         34450   Saturday
# 3     Sunday         26960     Sunday

# %% [markdown]
# ##Trend by hour

# %%
df_hour= (
    df_join_all
    .groupby('hour')
    .agg(total_ticket = ('ticket_id', 'count'))
    .reset_index()
)

# %%
df_hour
# Out:
#     hour  total_ticket
# 0      0          2352
# 1      1           964
# 2      2           398
# 3      3           159
# 4      4            74
# 5      5           146
# 6      6           536
# 7      7          1473
# 8      8          3865
# 9      9          7111
# 10    10          8793
# 11    11          9784
# 12    12         10794
# 13    13         10623
# 14    14          9854
# 15    15          9644
# 16    16         10452
# 17    17         11296
# 18    18         12328
# 19    19         12869
# 20    20         11372
# 21    21          8860
# 22    22          6595
# 23    23          4383

# %%
plt.figure(figsize=(13,4))

plt.fill_between(df_hour['hour'], df_hour['total_ticket'], color = 'cornflowerblue', alpha = 0.7)
x_values =[i for i in range(24)]
plt.xticks(x_values)
plt.title('#Ticket by hour')
plt.show()

# %%
# All histogram in 1 frame :

# %%
plt.figure(figsize=(13,8))

# chart 1 Month
ax1 = plt.subplot(2, 1, 1)
plt.fill_between(df_time_month['year_month'], df_time_month['total_ticket'], color = 'cornflowerblue', alpha = 0.7)
plt.title('#Ticket by months')
plt.xticks(rotation=90)

# chart day
ax2 = plt.subplot(2, 2, 3)
plt.fill_between(df_week_day['name_day'], df_week_day['total_ticket'], color = 'cornflowerblue', alpha = 0.7)
plt.title('#Ticket by week day')
plt.xticks(rotation=90)

# chart hour
ax3 = plt.subplot(2,2,4)
plt.fill_between(df_hour['hour'], df_hour['total_ticket'], color = 'cornflowerblue', alpha = 0.7)
x_values =[i for i in range(24)]
plt.xticks(x_values)
plt.title('#Ticket by hour')

plt.subplots_adjust(hspace=0.5, top=0.9)
plt.show()

# %% [markdown]
# ##3.3 Factor related to the customer's purchasing process

# %% [markdown]
# ##Payment Platform

# %%
df_join_all.head(2)
# Out:
#                           ticket_id  customer_id paying_method  theater_name  \
# 0  4f5200dcdcf2396b8d50ff84bf423f32       100009  money in app          13.0
# 1  07abbaf28c772692f0367ad992bb3184       100493  bank account         180.0
#
#                       device_number  original_price  discount_value  \
# 0  244764a57dbdeb8fe9b164847ad55183            9.90            2.10
# 1  8fa83cf46284aafd6e5da6c96f7862b5            8.66            1.48
#
#    final_price                    time  status_id  campaign_id  \
# 0         7.80 2022-07-08 17:46:36.145          1        83330
# 1         7.18 2022-07-15 20:44:09.952          1        83330
#
#                movie_name usergender        dob    campaign_type  \
# 0  Thor: Love And Thunder       Male 1989-02-25  direct discount
# 1  Thor: Love And Thunder       Male 1991-06-09  direct discount
#
#         description error_group       model platform  age_days  age  month  \
# 0  Order successful     unknown  iPhone13,1   mobile     13223   36      7
# 1  Order successful     unknown     browser  website     12389   33      7
#
#   name_day  hour year_month
# 0   Friday    17    2022-07
# 1   Friday    20    2022-07

# %%
df_platform = (
    df_join_all[df_join_all['platform'] != 'unknown']
    .groupby('platform')
    .agg(total_ticket = ('ticket_id', 'count'))
    .reset_index()
)

# %%
plt.figure(figsize=(6,4))
plt.pie(df_platform['total_ticket'], labels= df_platform['platform'],  colors = df_platform['platform'].replace({'mobile':'cornflowerblue', 'website':'lightblue'})) # Changed 'color' to 'colors'
plt.show()

# %%
#visualize mobile and website
plt.figure(figsize=(8,4))

plt.barh(
    df_platform['platform']
    , df_platform['total_ticket']
    , color = df_platform['platform'].replace({'mobile':'cornflowerblue', 'website':'lightblue'})
    , alpha = 0.7

)
for index,value in enumerate(df_platform['total_ticket']):
    plt.text(value, index, str(value))
plt.title('#Ticket by platform')
plt.show()

# %%
# By time:
df_platform_time = (
    df_join_all[df_join_all['platform'] != 'unknown']
    .groupby(['year_month', 'platform'])
    .agg(total_ticket = ('ticket_id', 'count'))
    .sort_values(by='year_month', ascending=True)
    .reset_index()
)

# %%
df_platform_time.head(10)
# Out:
#   year_month platform  total_ticket
# 0    2019-01   mobile          2019
# 1    2019-02   mobile          1626
# 2    2019-03   mobile          1004
# 3    2019-04   mobile          4069
# 4    2019-05   mobile          4430
# 5    2019-06   mobile          4387
# 6    2019-07   mobile          3872
# 7    2019-08   mobile          5444
# 8    2019-09   mobile          3278
# 9    2019-10   mobile          5284

# %%
# draw line chart
plt.figure(figsize=(13,4))
df_mobile_line = df_platform_time[df_platform_time['platform'] == 'mobile']
plt.plot(
    df_mobile_line['year_month']
    , df_mobile_line['total_ticket']
    ,label = 'mobile'
    , color = 'cornflowerblue'
    , marker = 'o'
)

df_web_line = df_platform_time[df_platform_time['platform'] == 'website']
plt.plot(
    df_web_line['year_month']
    , df_web_line['total_ticket']
    ,label = 'website'
    , color = 'lightblue'
    , marker = 'o'
)
plt.legend()
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# ##OS Version

# %%
df_join_all.head(2)
# Out:
#                           ticket_id  customer_id paying_method  theater_name  \
# 0  4f5200dcdcf2396b8d50ff84bf423f32       100009  money in app          13.0
# 1  07abbaf28c772692f0367ad992bb3184       100493  bank account         180.0
#
#                       device_number  original_price  discount_value  \
# 0  244764a57dbdeb8fe9b164847ad55183            9.90            2.10
# 1  8fa83cf46284aafd6e5da6c96f7862b5            8.66            1.48
#
#    final_price                    time  status_id  campaign_id  \
# 0         7.80 2022-07-08 17:46:36.145          1        83330
# 1         7.18 2022-07-15 20:44:09.952          1        83330
#
#                movie_name usergender        dob    campaign_type  \
# 0  Thor: Love And Thunder       Male 1989-02-25  direct discount
# 1  Thor: Love And Thunder       Male 1991-06-09  direct discount
#
#         description error_group       model platform  age_days  age  month  \
# 0  Order successful     unknown  iPhone13,1   mobile     13223   36      7
# 1  Order successful     unknown     browser  website     12389   33      7
#
#   name_day  hour year_month
# 0   Friday    17    2022-07
# 1   Friday    20    2022-07

# %%
# Discharge the OS version into groups :android_others , ios , unknown , browser
df_join_all['os_version'] = df_join_all['model'].apply(lambda x: 'ios' if ( 'iPhone' in x or 'iPod' in x)
                                                      else 'browser' if x == 'browser'
                                                      else 'unknown' if ('devicemodel' in x or 'unknown' in x)
                                                      else 'android & other')

# %%
df_join_all['os_version'].unique()
# Out:
# array(['ios', 'browser', 'unknown', 'android & other'], dtype=object)

# %%
df_os = (
    df_join_all
    .groupby('os_version')
    .agg(total_ticket = ('ticket_id', 'count'))
    .sort_values(by='total_ticket', ascending=True).reset_index()
)

# %%
df_os
# Out:
#         os_version  total_ticket
# 0          browser         13377
# 1  android & other         21092
# 2              ios         51402
# 3          unknown         68854

# %%
plt.figure(figsize=(12,3))

ax1 = plt.subplot(1,2,1)
plt.barh(
    df_os['os_version']
    , df_os['total_ticket']
    , color = df_os['os_version'].replace({'android & other':'cornflowerblue', 'ios':'lightblue', 'browser':'slategrey', 'unknown':'lightskyblue'})
    , alpha = 0.7
)
for index,value in enumerate(df_os['total_ticket']):
    plt.text(value, index, str(value))
plt.title('#Ticket by OS')
plt.xticks(rotation=90)


ax2 = plt.subplot(1,2,2)
plt.pie(df_os['total_ticket'], labels= df_os['os_version'], colors= df_os['os_version'].replace({'android & other':'cornflowerblue', 'ios': 'lightblue','browser' : 'slategrey','unknown' : 'lightskyblue'}), autopct= '%1.0f%%', startangle=90)
plt.show()

# %%
df_os_time = (
    df_join_all
    .groupby(['year_month', 'os_version'])
    .agg(total_ticket = ('ticket_id', 'count'))
    .sort_values(by='year_month', ascending=True)
    .reset_index()
)

# %%
df_os_time.head(10)
# Out:
#   year_month       os_version  total_ticket
# 0    2019-01  android & other           713
# 1    2019-01              ios          1233
# 2    2019-01          unknown            73
# 3    2019-02  android & other           542
# 4    2019-02              ios          1074
# 5    2019-02          unknown            10
# 6    2019-03  android & other           371
# 7    2019-03              ios           631
# 8    2019-03          unknown             2
# 9    2019-04  android & other          1519

# %%
#Solving data PIVOT to draw chart :

df_os_time = (
    df_join_all
    .pivot_table(index='year_month', columns='os_version', values='ticket_id', aggfunc='count')
    .reset_index()
)

# %%
df_os_time.head(10)
# Out:
# os_version year_month  android & other  browser     ios  unknown
# 0             2019-01            713.0      NaN  1233.0     73.0
# 1             2019-02            542.0      NaN  1074.0     10.0
# 2             2019-03            371.0      NaN   631.0      2.0
# 3             2019-04           1519.0      NaN  2541.0      9.0
# 4             2019-05           1601.0      NaN  2826.0      3.0
# 5             2019-06           1575.0      NaN  2808.0      4.0
# 6             2019-07           1373.0      NaN  2499.0      NaN
# 7             2019-08           1797.0      NaN  3642.0      5.0
# 8             2019-09           1122.0      NaN  2151.0      5.0
# 9             2019-10           1964.0      NaN  3313.0      7.0

# %%
plt.figure(figsize=(12,8))

ax1 = plt.subplot(2,2,1)
plt.barh(
    df_os['os_version']
    , df_os['total_ticket']
    , color = df_os['os_version'].replace({'android & other':'cornflowerblue', 'ios':'lightblue', 'browser':'slategrey', 'unknown':'lightskyblue'})
    , alpha = 0.7
)
for index,value in enumerate(df_os['total_ticket']):
    plt.text(value, index, str(value))
plt.title('#Ticket by OS')


ax2 = plt.subplot(2,2,2)
plt.pie(df_os['total_ticket'], labels= df_os['os_version'], colors= df_os['os_version'].replace({'android & other':'cornflowerblue', 'ios': 'lightblue','browser' : 'slategrey','unknown' : 'lightskyblue'}), autopct= '%1.0f%%', startangle=90)

ax3 = plt.subplot(2,1,2)
plt.fill_between(df_os_time['year_month'], df_os_time['android & other'], color = 'cornflowerblue',label =' android & other' ,alpha = 0.7)
plt.fill_between(df_os_time['year_month'], df_os_time['ios'], color = 'lightblue',label = 'ios', alpha = 0.7)
plt.fill_between(df_os_time['year_month'], df_os_time['browser'], color = 'slategrey',label = 'browser', alpha = 0.7)
plt.fill_between(df_os_time['year_month'], df_os_time['unknown'], color = 'lightskyblue',label = 'unknown', alpha = 0.7)
plt.title('#Ticket of OS version by time')
plt.ylabel('#Ticket')
plt.legend(loc='upper left')
plt.xticks(rotation=90)

plt.show()

# %% [markdown]
# ##Payment Method

# %%
df_join_all.head(2)
# Out:
#                           ticket_id  customer_id paying_method  theater_name  \
# 0  4f5200dcdcf2396b8d50ff84bf423f32       100009  money in app          13.0
# 1  07abbaf28c772692f0367ad992bb3184       100493  bank account         180.0
#
#                       device_number  original_price  discount_value  \
# 0  244764a57dbdeb8fe9b164847ad55183            9.90            2.10
# 1  8fa83cf46284aafd6e5da6c96f7862b5            8.66            1.48
#
#    final_price                    time  status_id  campaign_id  \
# 0         7.80 2022-07-08 17:46:36.145          1        83330
# 1         7.18 2022-07-15 20:44:09.952          1        83330
#
#                movie_name usergender        dob    campaign_type  \
# 0  Thor: Love And Thunder       Male 1989-02-25  direct discount
# 1  Thor: Love And Thunder       Male 1991-06-09  direct discount
#
#         description error_group       model platform  age_days  age  month  \
# 0  Order successful     unknown  iPhone13,1   mobile     13223   36      7
# 1  Order successful     unknown     browser  website     12389   33      7
#
#   name_day  hour year_month os_version
# 0   Friday    17    2022-07        ios
# 1   Friday    20    2022-07    browser

# %%
df_method = (
     df_join_all[( df_join_all['status_id']== 1) & (df_join_all['paying_method'] != 'other')]
    .groupby('paying_method')
    .agg(total_ticket = ('ticket_id', 'count'))
    .sort_values(by='total_ticket', ascending=False)
    .reset_index()
)

# %%
#Solving data PIVOT to draw chart :

df_method_time = (
    df_join_all[( df_join_all['status_id']== 1) & (df_join_all['paying_method'] != 'other')]
    .pivot_table(index='year_month', columns='paying_method', values='ticket_id', aggfunc='count')
    .reset_index()
)

# %%
df_method_time.head(10)
# Out:
# paying_method year_month  bank account  credit card  debit card  money in app
# 0                2019-01         487.0        336.0        93.0         443.0
# 1                2019-02         484.0        370.0        93.0         480.0
# 2                2019-03         304.0        225.0        74.0         263.0
# 3                2019-04        1050.0        705.0       189.0        1246.0
# 4                2019-05        1092.0        903.0       212.0        1410.0
# 5                2019-06        1074.0        962.0       249.0        1319.0
# 6                2019-07         916.0        782.0       252.0        1215.0
# 7                2019-08        1367.0       1142.0       321.0        1684.0
# 8                2019-09         774.0        711.0       219.0        1068.0
# 9                2019-10        1280.0        914.0       309.0        1833.0

# %%
# 1 Frame
plt.figure(figsize=(12,8))

ax1 = plt.subplot(2,2,1)
plt.barh(
    df_method['paying_method']
    , df_method['total_ticket']
    , color = df_method['paying_method'].replace({'bank account':'cornflowerblue', 'credit card':'lightblue', 'debit card':'slategrey', 'money in app':'lightskyblue'})
    , alpha = 0.7
)
for index,value in enumerate(df_method['total_ticket']):
    plt.text(value, index, str(value))
plt.title('#Ticket by method')


ax2 = plt.subplot(2,2,2)
plt.pie(df_method['total_ticket'], labels= df_method['paying_method'], colors= df_method['paying_method'].replace({'bank account':'cornflowerblue', 'credit card':'lightblue', 'debit card':'slategrey', 'money in app':'lightskyblue'}), autopct= '%1.0f%%', startangle=90)

ax3 = plt.subplot(2,1,2)
plt.fill_between(df_method_time['year_month'], df_method_time['bank account'], color = 'cornflowerblue',label =' bank account' ,alpha = 0.7)
plt.fill_between(df_method_time['year_month'], df_method_time['credit card'], color = 'lightblue',label = 'credit card', alpha = 0.7)
plt.fill_between(df_method_time['year_month'], df_method_time['debit card'], color = 'slategrey',label = 'debit card', alpha = 0.7)
plt.fill_between(df_method_time['year_month'], df_method_time['money in app'], color = 'lightskyblue',label = 'money in app', alpha = 0.7)
plt.title('#Ticket of method by time')
plt.ylabel('#Ticket')
plt.legend(loc='upper left')
plt.xticks(rotation=90)

plt.show()

# %%
#drawing histogram 100%
df_method_time = (
    df_join_all[( df_join_all['status_id']== 1) & (df_join_all['paying_method'] != 'other')]
    .pivot_table(index='year_month', columns='paying_method', values='ticket_id', aggfunc='count')
    .reset_index()
)
df_method_time_pct = df_method_time.copy()
df_method_time_pct = df_method_time_pct.fillna(0)

df_method_time_pct['total'] = df_method_time_pct.iloc[:,1:].sum(axis=1)
for i in df_method_time_pct.columns[1:5]:
    df_method_time_pct[i+'_pct'] = df_method_time_pct[i]/df_method_time_pct['total']
df_method_time_pct.head(10)
# Out:
# paying_method year_month  bank account  credit card  debit card  money in app  \
# 0                2019-01         487.0        336.0        93.0         443.0
# 1                2019-02         484.0        370.0        93.0         480.0
# 2                2019-03         304.0        225.0        74.0         263.0
# 3                2019-04        1050.0        705.0       189.0        1246.0
# 4                2019-05        1092.0        903.0       212.0        1410.0
# 5                2019-06        1074.0        962.0       249.0        1319.0
# 6                2019-07         916.0        782.0       252.0        1215.0
# 7                2019-08        1367.0       1142.0       321.0        1684.0
# 8                2019-09         774.0        711.0       219.0        1068.0
# 9                2019-10        1280.0        914.0       309.0        1833.0
#
# paying_method   total  bank account_pct  credit card_pct  debit card_pct  \
# 0              1359.0          0.358352         0.247241        0.068433
# 1              1427.0          0.339173         0.259285        0.065172
# 2               866.0          0.351039         0.259815        0.085450
# 3              3190.0          0.329154         0.221003        0.059248
# 4              3617.0          0.301908         0.249654        0.058612
# 5              3604.0          0.298002         0.266926        0.069090
# 6              3165.0          0.289415         0.247077        0.079621
# 7              4514.0          0.302836         0.252991        0.071112
# 8              2772.0          0.279221         0.256494        0.079004
# 9              4336.0          0.295203         0.210793        0.071264
#
# paying_method  money in app_pct
# 0                      0.325975
# 1                      0.336370
# 2                      0.303695
# 3                      0.390596
# 4                      0.389826
# 5                      0.365982
# 6                      0.383886
# 7                      0.373062
# 8                      0.385281
# 9                      0.422740

# %%
# 1 Frame
plt.figure(figsize=(12,8))

ax1 = plt.subplot(3,2,1)
plt.barh(
    df_method['paying_method']
    , df_method['total_ticket']
    , color = df_method['paying_method'].replace({'bank account':'cornflowerblue', 'credit card':'lightblue', 'debit card':'slategrey', 'money in app':'lightskyblue'})
    , alpha = 0.7
)
for index,value in enumerate(df_method['total_ticket']):
    plt.text(value, index, str(value))
plt.title('#Ticket by method')


ax2 = plt.subplot(3,2,2)
plt.pie(df_method['total_ticket'], labels= df_method['paying_method'], colors= df_method['paying_method'].replace({'bank account':'cornflowerblue', 'credit card':'lightblue', 'debit card':'slategrey', 'money in app':'lightskyblue'}), autopct= '%1.0f%%', startangle=90)

ax3 = plt.subplot(3,1,2)
plt.fill_between(df_method_time['year_month'], df_method_time['bank account'], color = 'cornflowerblue',label =' bank account' ,alpha = 0.7)
plt.fill_between(df_method_time['year_month'], df_method_time['credit card'], color = 'lightblue',label = 'credit card', alpha = 0.7)
plt.fill_between(df_method_time['year_month'], df_method_time['debit card'], color = 'slategrey',label = 'debit card', alpha = 0.7)
plt.fill_between(df_method_time['year_month'], df_method_time['money in app'], color = 'lightskyblue',label = 'money in app', alpha = 0.7)
plt.title('#Ticket of method by time')
plt.ylabel('#Ticket')
plt.legend(loc='upper left')
plt.xticks(rotation=90)


ax4 = plt.subplot(3,1,3)
plt.stackplot(df_method_time_pct['year_month'], df_method_time_pct['bank account_pct'], df_method_time_pct['credit card_pct'], df_method_time_pct['debit card_pct'], df_method_time_pct['money in app_pct'],
labels = ['bank account', 'credit card', 'debit card', 'money in app'], colors=['cornflowerblue', 'lightblue', 'slategrey', 'lightskyblue'])
plt.title('#Ticket of method by time')
plt.ylabel('#Ticket')
plt.legend(loc='upper right', bbox_to_anchor=(1.15, 1))
plt.xticks(rotation=90)

plt.subplots_adjust(hspace=0.7, top=0.9)
plt.show()

# %% [markdown]
# ##Promotion

# %%
df_join_all['campaign_type'].unique()
# Out:
# array(['direct discount', 'unknown', 'voucher', 'reward point'],
#       dtype=object)

# %%
df_join_all['type'] = df_join_all['campaign_type'].apply(lambda x: 'non promotion' if x== 'unknown' else 'promotion')

# %%
df_join_all.head(2)
# Out:
#                           ticket_id  customer_id paying_method  theater_name  \
# 0  4f5200dcdcf2396b8d50ff84bf423f32       100009  money in app          13.0
# 1  07abbaf28c772692f0367ad992bb3184       100493  bank account         180.0
#
#                       device_number  original_price  discount_value  \
# 0  244764a57dbdeb8fe9b164847ad55183            9.90            2.10
# 1  8fa83cf46284aafd6e5da6c96f7862b5            8.66            1.48
#
#    final_price                    time  status_id  campaign_id  \
# 0         7.80 2022-07-08 17:46:36.145          1        83330
# 1         7.18 2022-07-15 20:44:09.952          1        83330
#
#                movie_name usergender        dob    campaign_type  \
# 0  Thor: Love And Thunder       Male 1989-02-25  direct discount
# 1  Thor: Love And Thunder       Male 1991-06-09  direct discount
#
#         description error_group       model platform  age_days  age  month  \
# 0  Order successful     unknown  iPhone13,1   mobile     13223   36      7
# 1  Order successful     unknown     browser  website     12389   33      7
#
#   name_day  hour year_month os_version       type
# 0   Friday    17    2022-07        ios  promotion
# 1   Friday    20    2022-07    browser  promotion

# %%
df_type = (
     df_join_all[( df_join_all['status_id']== 1) & (df_join_all['paying_method'] != 'other')]
    .groupby('type')
    .agg(total_ticket = ('ticket_id', 'count'))
    .sort_values(by='total_ticket', ascending=False)
    .reset_index()
)

# %%
df_type
# Out:
#             type  total_ticket
# 0      promotion         78522
# 1  non promotion         55155

# %%
#Solving data PIVOT to draw chart :

df_type_time = (
    df_join_all[( df_join_all['status_id']== 1) & (df_join_all['paying_method'] != 'other')]
    .pivot_table(index='year_month', columns='type', values='ticket_id', aggfunc='count')
    .reset_index()
)
df_type_time_pct = df_type_time.copy()
df_type_time_pct = df_type_time_pct.fillna(0)

df_type_time_pct['total'] = df_type_time_pct.iloc[:,1:].sum(axis=1)
for i in df_type_time_pct.columns[1:3]:
    df_type_time_pct[i+'_pct'] = df_type_time_pct[i]/df_type_time_pct['total']
df_type_time_pct.head(5)
# Out:
# type year_month  non promotion  promotion   total  non promotion_pct  \
# 0       2019-01          517.0      842.0  1359.0           0.380427
# 1       2019-02         1335.0       92.0  1427.0           0.935529
# 2       2019-03          835.0       31.0   866.0           0.964203
# 3       2019-04         1699.0     1491.0  3190.0           0.532602
# 4       2019-05         1564.0     2053.0  3617.0           0.432403
#
# type  promotion_pct
# 0          0.619573
# 1          0.064471
# 2          0.035797
# 3          0.467398
# 4          0.567597

# %%
# 1 Frame
plt.figure(figsize=(12, 8))

ax1 = plt.subplot(3, 2, 1)
plt.barh(
    df_type['type'],
    df_type['total_ticket'],
    color=df_type['type'].replace({'non promotion': 'cornflowerblue', 'promotion': 'tomato'}),
    alpha=0.7
)
for index, value in enumerate(df_type['total_ticket']):
    plt.text(value, index, str(value))
plt.title('#Ticket by type')

ax2 = plt.subplot(3, 2, 2)

plt.pie(df_type['total_ticket'], labels=df_type['type'], colors=['cornflowerblue', 'tomato'], autopct='%1.0f%%', startangle=90)

ax3 = plt.subplot(3, 1, 2)
plt.fill_between(df_type_time['year_month'], df_type_time['non promotion'], color='cornflowerblue', label='non promotion', alpha=0.7)
plt.fill_between(df_type_time['year_month'], df_type_time['promotion'], color='tomato', label='promotion', alpha=0.7)

plt.title('#Ticket of type by time')
plt.ylabel('#Ticket')
plt.legend(loc='upper left')
plt.xticks(rotation=90)

ax4 = plt.subplot(3, 1, 3)
# Use df_type_time_pct for percentage values
plt.stackplot(df_type_time_pct['year_month'], df_type_time_pct['non promotion_pct'], df_type_time_pct['promotion_pct'],
              labels=['non promotion', 'promotion'], colors=['cornflowerblue', 'tomato'])
plt.title('#Ticket of type by time')
plt.ylabel('#Ticket')
plt.legend(loc='upper right', bbox_to_anchor=(1.15, 1))
plt.xticks(rotation=90)

plt.subplots_adjust(hspace=0.7, top=0.9)
plt.show()

# %% [markdown]
# ## Which movies they watch ?

# %%
df_film_sum = (
    df_join_all[df_join_all['status_id'] == 1]
    .groupby('movie_name')
    .agg(total_ticket = ('ticket_id', 'count'),
         total_customer = ('customer_id', 'nunique'),
         revenue = ('final_price', 'sum'))
    .sort_values(by='total_ticket', ascending=False)
    .reset_index()
)

# %%
df_film_sum.head(10)
# Out:
#                                     movie_name  total_ticket  total_customer  \
# 0  Doctor Strange In The Multiverse Of Madness          8615            8409
# 1                     Minions: The Rise Of Gru          7224            7014
# 2                     Avatar: The Way Of Water          5870            5612
# 3                       Thor: Love And Thunder          5589            5478
# 4                                    Peninsula          5499            5365
# 5             Black Panther 2: Wakanda Forever          3847            3790
# 6                                   Black Adam          3229            3186
# 7                            Avengers: Endgame          3219            3135
# 8                                Dad I'm Sorry          3023            2817
# 9                                 Love Destiny          2411            2376
#
#     revenue
# 0  65579.98
# 1  56530.93
# 2  59830.95
# 3  43372.90
# 4  41208.44
# 5  26860.28
# 6  23159.34
# 7  26690.48
# 8  25863.28
# 9  18345.61

# %%
list_film = df_film_sum[df_film_sum['total_ticket'] > 1000] ['movie_name'].unique()
list_selected_film = list_film.tolist()

# %%
list_selected_film
# Out:
# ['Doctor Strange In The Multiverse Of Madness',
#  'Minions: The Rise Of Gru',
#  'Avatar: The Way Of Water',
#  'Thor: Love And Thunder',
#  'Peninsula',
#  'Black Panther 2: Wakanda Forever',
#  'Black Adam',
#  'Avengers: Endgame',
#  "Dad I'm Sorry",
#  'Love Destiny',
#  'You And Trinh',
#  'Fast & Furious Presents: Hobbs & Shaw',
#  'Emergency Declaration',
#  'Jurassic World Dominion',
#  'Godzilla Vs. Kong',
#  'Detective Conan: The Bride Of Halloween',
#  'Joker',
#  'Spider-Man: No Way Home',
#  'Batman',
#  'Blood Moon Party',
#  'Fantastic Beasts: Secrets Of Dumbledore',
#  'Top Gun: Maverick',
#  'Naked Truth',
#  "Doraemon: Nobita's Little Star Wars 2021",
#  'One Piece Film: Red',
#  'Confidential Assignment 2: International',
#  'Extremely Easy Job',
#  'Morbius',
#  'Spider-Man Far From Home',
#  'Maleficent',
#  'Face Off: 48h',
#  'Parasite']

# %%
df_movie_time_pivot = (
    df_join_all[(df_join_all['status_id'] == 1) & (df_join_all['movie_name'].isin(list_selected_film))]
    .pivot_table(index='year_month', columns='movie_name', values='ticket_id', aggfunc='count')
    .reset_index()
)

# %%
df_movie_time_pivot.head(20)
# Out:
# movie_name year_month  Avatar: The Way Of Water  Avengers: Endgame  Batman  \
# 0             2019-04                       NaN             2081.0     NaN
# 1             2019-05                       NaN             1130.0     NaN
# 2             2019-06                       NaN                8.0     NaN
# 3             2019-07                       NaN                NaN     NaN
# 4             2019-08                       NaN                NaN     NaN
# 5             2019-09                       NaN                NaN     NaN
# 6             2019-10                       NaN                NaN     NaN
# 7             2019-11                       NaN                NaN     NaN
# 8             2020-02                       NaN                NaN     NaN
# 9             2020-03                       NaN                NaN     NaN
# 10            2020-05                       NaN                NaN     NaN
# 11            2020-06                       NaN                NaN     NaN
# 12            2020-07                       NaN                NaN     NaN
# 13            2020-08                       NaN                NaN     NaN
# 14            2020-10                       NaN                NaN     NaN
# 15            2020-11                       NaN                NaN     NaN
# 16            2020-12                       NaN                NaN     NaN
# 17            2021-02                       NaN                NaN     NaN
# 18            2021-03                       NaN                NaN     NaN
# 19            2021-04                       NaN                NaN     NaN
#
# movie_name  Black Adam  Black Panther 2: Wakanda Forever  Blood Moon Party  \
# 0                  NaN                               NaN               NaN
# 1                  NaN                               NaN               NaN
# 2                  NaN                               NaN               NaN
# 3                  NaN                               NaN               NaN
# 4                  NaN                               NaN               NaN
# 5                  NaN                               NaN               NaN
# 6                  NaN                               NaN               NaN
# 7                  NaN                               NaN               NaN
# 8                  NaN                               NaN               NaN
# 9                  NaN                               NaN               NaN
# 10                 NaN                               NaN               NaN
# 11                 NaN                               NaN               NaN
# 12                 NaN                               NaN               NaN
# 13                 NaN                               NaN               NaN
# 14                 NaN                               NaN             816.0
# 15                 NaN                               NaN             502.0
# 16                 NaN                               NaN              68.0
# 17                 NaN                               NaN               7.0
# 18                 NaN                               NaN               NaN
# 19                 NaN                               NaN               NaN
#
# movie_name  Confidential Assignment 2: International  Dad I'm Sorry  \
# 0                                                NaN            NaN
# 1                                                NaN            NaN
# 2                                                NaN            NaN
# 3                                                NaN            NaN
# 4                                                NaN            NaN
# 5                                                NaN            NaN
# 6                                                NaN            NaN
# 7                                                NaN            NaN
# 8                                                NaN            NaN
# 9                                                NaN            NaN
# 10                                               NaN            NaN
# 11                                               NaN            NaN
# 12                                               NaN            NaN
# 13                                               NaN            NaN
# 14                                               NaN            NaN
# 15                                               NaN            NaN
# 16                                               NaN            NaN
# 17                                               NaN            NaN
# 18                                               NaN         2869.0
# 19                                               NaN          145.0
#
# movie_name  Detective Conan: The Bride Of Halloween  \
# 0                                               NaN
# 1                                               NaN
# 2                                               NaN
# 3                                               NaN
# 4                                               NaN
# 5                                               NaN
# 6                                               NaN
# 7                                               NaN
# 8                                               NaN
# 9                                               NaN
# 10                                              NaN
# 11                                              NaN
# 12                                              NaN
# 13                                              NaN
# 14                                              NaN
# 15                                              NaN
# 16                                              NaN
# 17                                              NaN
# 18                                              NaN
# 19                                              NaN
#
# movie_name  Doctor Strange In The Multiverse Of Madness  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# 5                                                   NaN
# 6                                                   NaN
# 7                                                   NaN
# 8                                                   NaN
# 9                                                   NaN
# 10                                                  NaN
# 11                                                  NaN
# 12                                                  NaN
# 13                                                  NaN
# 14                                                  NaN
# 15                                                  NaN
# 16                                                  NaN
# 17                                                  NaN
# 18                                                  NaN
# 19                                                  NaN
#
# movie_name  Doraemon: Nobita's Little Star Wars 2021  Emergency Declaration  \
# 0                                                NaN                    NaN
# 1                                                NaN                    NaN
# 2                                                NaN                    NaN
# 3                                                NaN                    NaN
# 4                                                NaN                    NaN
# 5                                                NaN                    NaN
# 6                                                NaN                    NaN
# 7                                                NaN                    NaN
# 8                                                NaN                    NaN
# 9                                                NaN                    NaN
# 10                                               NaN                    NaN
# 11                                               NaN                    NaN
# 12                                               NaN                    NaN
# 13                                               NaN                    NaN
# 14                                               NaN                    NaN
# 15                                               NaN                    NaN
# 16                                               NaN                    NaN
# 17                                               NaN                    NaN
# 18                                               NaN                    NaN
# 19                                               NaN                    NaN
#
# movie_name  Extremely Easy Job  Face Off: 48h  \
# 0                          NaN            NaN
# 1                          NaN            NaN
# 2                          NaN            NaN
# 3                          NaN            NaN
# 4                          NaN            NaN
# 5                          NaN            NaN
# 6                          NaN            NaN
# 7                          NaN            NaN
# 8                          NaN            NaN
# 9                          NaN            NaN
# 10                         NaN            NaN
# 11                         NaN            NaN
# 12                         NaN            NaN
# 13                         NaN            NaN
# 14                         NaN            NaN
# 15                         NaN            NaN
# 16                         NaN            NaN
# 17                         NaN            NaN
# 18                         NaN            NaN
# 19                         NaN         1003.0
#
# movie_name  Fantastic Beasts: Secrets Of Dumbledore  \
# 0                                               NaN
# 1                                               NaN
# 2                                               NaN
# 3                                               NaN
# 4                                               NaN
# 5                                               NaN
# 6                                               NaN
# 7                                               NaN
# 8                                               NaN
# 9                                               NaN
# 10                                              NaN
# 11                                              NaN
# 12                                              NaN
# 13                                              NaN
# 14                                              NaN
# 15                                              NaN
# 16                                              NaN
# 17                                              NaN
# 18                                              NaN
# 19                                              NaN
#
# movie_name  Fast & Furious Presents: Hobbs & Shaw  Godzilla Vs. Kong   Joker  \
# 0                                             NaN                NaN     NaN
# 1                                             NaN                NaN     NaN
# 2                                             NaN                NaN     NaN
# 3                                           126.0                NaN     NaN
# 4                                          1950.0                NaN     NaN
# 5                                            31.0                NaN    34.0
# 6                                             NaN                NaN  1405.0
# 7                                             NaN                NaN     3.0
# 8                                             NaN                NaN     5.0
# 9                                             NaN                NaN     NaN
# 10                                            4.0                NaN     NaN
# 11                                            1.0                NaN     NaN
# 12                                            NaN                NaN     NaN
# 13                                            NaN                NaN     NaN
# 14                                            NaN                NaN     NaN
# 15                                            NaN                NaN     NaN
# 16                                            NaN                NaN     NaN
# 17                                            NaN                NaN     NaN
# 18                                            NaN             1259.0     NaN
# 19                                            NaN              473.0     NaN
#
# movie_name  Jurassic World Dominion  Love Destiny  Maleficent  \
# 0                               NaN           NaN         NaN
# 1                               NaN           NaN         NaN
# 2                               NaN           NaN         NaN
# 3                               NaN           NaN         NaN
# 4                               NaN           NaN         NaN
# 5                               NaN           NaN         NaN
# 6                               NaN           NaN      1008.0
# 7                               NaN           NaN        79.0
# 8                               NaN           NaN         NaN
# 9                               NaN           NaN         NaN
# 10                              NaN           NaN         NaN
# 11                              NaN           NaN         NaN
# 12                              NaN           NaN         NaN
# 13                              NaN           NaN         NaN
# 14                              NaN           NaN         NaN
# 15                              NaN           NaN         NaN
# 16                              NaN           NaN         NaN
# 17                              NaN           NaN         NaN
# 18                              NaN           NaN         NaN
# 19                              NaN           NaN         NaN
#
# movie_name  Minions: The Rise Of Gru  Morbius  Naked Truth  \
# 0                                NaN      NaN          NaN
# 1                                NaN      NaN          NaN
# 2                                NaN      NaN          NaN
# 3                                NaN      NaN          NaN
# 4                                NaN      NaN          NaN
# 5                                NaN      NaN          NaN
# 6                                NaN      NaN          NaN
# 7                                NaN      NaN          NaN
# 8                                NaN      NaN          NaN
# 9                                NaN      NaN          NaN
# 10                               NaN      NaN          NaN
# 11                               NaN      NaN          NaN
# 12                               NaN      NaN          NaN
# 13                               NaN      NaN          NaN
# 14                               NaN      NaN          NaN
# 15                               NaN      NaN          NaN
# 16                               NaN      NaN          NaN
# 17                               NaN      NaN          NaN
# 18                               NaN      NaN          NaN
# 19                               NaN      NaN          NaN
#
# movie_name  One Piece Film: Red  Parasite  Peninsula  \
# 0                           NaN       NaN        NaN
# 1                           NaN       NaN        NaN
# 2                           NaN     751.0        NaN
# 3                           NaN     286.0        NaN
# 4                           NaN       NaN        NaN
# 5                           NaN       NaN        NaN
# 6                           NaN       NaN        NaN
# 7                           NaN       NaN        NaN
# 8                           NaN      29.0        NaN
# 9                           NaN       2.0        NaN
# 10                          NaN       NaN        NaN
# 11                          NaN       NaN        NaN
# 12                          NaN       NaN      196.0
# 13                          NaN       NaN       15.0
# 14                          NaN       NaN        NaN
# 15                          NaN       NaN        NaN
# 16                          NaN       NaN        NaN
# 17                          NaN       NaN        NaN
# 18                          NaN       NaN        NaN
# 19                          NaN       NaN        NaN
#
# movie_name  Spider-Man Far From Home  Spider-Man: No Way Home  \
# 0                                NaN                      NaN
# 1                                NaN                      NaN
# 2                               28.0                      NaN
# 3                             1125.0                      NaN
# 4                                NaN                      NaN
# 5                                NaN                      NaN
# 6                                NaN                      NaN
# 7                                NaN                      NaN
# 8                                NaN                      NaN
# 9                                NaN                      NaN
# 10                               NaN                      NaN
# 11                               NaN                      NaN
# 12                               NaN                      NaN
# 13                               NaN                      NaN
# 14                               NaN                      NaN
# 15                               NaN                      NaN
# 16                               NaN                      NaN
# 17                               NaN                      NaN
# 18                               NaN                      NaN
# 19                               NaN                      NaN
#
# movie_name  Thor: Love And Thunder  Top Gun: Maverick  You And Trinh
# 0                              NaN                NaN            NaN
# 1                              NaN                NaN            NaN
# 2                              NaN                NaN            NaN
# 3                              NaN                NaN            NaN
# 4                              NaN                NaN            NaN
# 5                              NaN                NaN            NaN
# 6                              NaN                NaN            NaN
# 7                              NaN                NaN            NaN
# 8                              NaN                NaN            NaN
# 9                              NaN                NaN            NaN
# 10                             NaN                NaN            NaN
# 11                             NaN                NaN            NaN
# 12                             NaN                NaN            NaN
# 13                             NaN                NaN            NaN
# 14                             NaN                NaN            NaN
# 15                             NaN                NaN            NaN
# 16                             NaN                NaN            NaN
# 17                             NaN                NaN            NaN
# 18                             NaN                NaN            NaN
# 19                             NaN                NaN            NaN

# %%
# Bar chart with collapse column
ax = df_movie_time_pivot.plot(x = 'year_month', kind='bar', stacked=True, figsize=(15,6), width=0.8, alpha = 0.7)

ax.set_title('Movie name trend')
ax.set_ylabel('Number of Tickets')

plt.legend(title='Movie', bbox_to_anchor=(1.35, 1), loc='upper right')
plt.xticks(rotation=90)
ax.set_ylabel('Number of Tickets')

plt.show()

# %% [markdown]
# ##3.4 Customer value dimension

# %% [markdown]
# Goal : analyst the value of one customer brings
# *   Frequency: count_day, month
# *   Monetary : total_money ,total_discount
# *   Success rate : number_success/total
# *   Promotion_rate : number_promotion/ total_success
# *  Discount_rate = sum_discount / sum_money

# %%
df_join_all.head(2)
# Out:
#                           ticket_id  customer_id paying_method  theater_name  \
# 0  4f5200dcdcf2396b8d50ff84bf423f32       100009  money in app          13.0
# 1  07abbaf28c772692f0367ad992bb3184       100493  bank account         180.0
#
#                       device_number  original_price  discount_value  \
# 0  244764a57dbdeb8fe9b164847ad55183            9.90            2.10
# 1  8fa83cf46284aafd6e5da6c96f7862b5            8.66            1.48
#
#    final_price                    time  status_id  campaign_id  \
# 0         7.80 2022-07-08 17:46:36.145          1        83330
# 1         7.18 2022-07-15 20:44:09.952          1        83330
#
#                movie_name usergender        dob    campaign_type  \
# 0  Thor: Love And Thunder       Male 1989-02-25  direct discount
# 1  Thor: Love And Thunder       Male 1991-06-09  direct discount
#
#         description error_group       model platform  age_days  age  month  \
# 0  Order successful     unknown  iPhone13,1   mobile     13223   36      7
# 1  Order successful     unknown     browser  website     12389   33      7
#
#   name_day  hour year_month os_version       type
# 0   Friday    17    2022-07        ios  promotion
# 1   Friday    20    2022-07    browser  promotion

# %%
# calculate all the index above:
# calculate the index of tickets that successed:
def calculate_n_promotion(x):
  return ( x == 'promotion').sum()

df_success_metric = (
    df_join_all[df_join_all['status_id'] == 1]
    .assign(date = pd.to_datetime(df_join_all['time']).dt.date)

    .groupby('customer_id')
    .agg(
        n_success = ('ticket_id', 'count'),
        s_money = ('original_price', 'sum'),
        s_discount = ('discount_value', 'sum'),
        n_days = ('date', 'nunique'),
        n_months = ('year_month', 'nunique'),
        n_promotion = ('type' , calculate_n_promotion)
    )
    .reset_index()
)

# %%
#calculate index : total and error
def calculate_n_failed(x):
  return ( x != 1).sum()

df_failed_metric = (
    df_join_all
    .groupby('customer_id')
    .agg(
        n_total = ('ticket_id', 'count'),
        n_failed = ('status_id', calculate_n_failed)
    )
    .reset_index()
)

# %%
df_success_metric.head(2)
# Out:
#    customer_id  n_success  s_money  s_discount  n_days  n_months  n_promotion
# 0       100001          1     7.42        2.06       1         1            1
# 1       100003          6    60.95        2.56       6         6            1

# %%
df_failed_metric.head(2)
# Out:
#    customer_id  n_total  n_failed
# 0       100001        1         0
# 1       100003        6         0

# %%
# join 2 tables :
df_customer_value = (
    pd.merge(df_failed_metric, df_success_metric, on='customer_id', how='left')
    .fillna(0)
)

# %%
df_customer_value.head(5)
# Out:
#    customer_id  n_total  n_failed  n_success  s_money  s_discount  n_days  \
# 0       100001        1         0        1.0     7.42        2.06     1.0
# 1       100003        6         0        6.0    60.95        2.56     6.0
# 2       100004        1         0        1.0    32.25        0.00     1.0
# 3       100005        1         0        1.0     9.49        2.06     1.0
# 4       100006        1         0        1.0    12.37        0.00     1.0
#
#    n_months  n_promotion
# 0       1.0          1.0
# 1       6.0          1.0
# 2       1.0          0.0
# 3       1.0          1.0
# 4       1.0          0.0

# %%
df_customer_value['success_rate'] = df_customer_value['n_success'] / df_customer_value['n_total']
df_customer_value['promotion_rate'] = df_customer_value['n_promotion'] / df_customer_value['n_success']
df_customer_value['discount_rate'] = df_customer_value['s_discount'] / df_customer_value['s_money']

# %%
# visualize all value by using histogram :

df_customer_value.iloc[:,1:].hist(figsize=(12,10), bins=20, grid=False, color='cornflowerblue')
plt.show()

# %% [markdown]
# >- ***Note***
#
# >> - **n_total**: Most of the customer buy tickets low(1-2 tickets) , but some of customers buy alot => check
#
# >> - **success_rate**: above 10% SR = 0%
# >> - **promotion_rate**: above 60000 customers just join promotion when (rate = 100% )
# >> - **n_promotion**:
#  60000 customers take promotion one time (relevent to promotion_rate = 100% )?

# %% [markdown]
# ## Frequency and anomaly behavior

# %%
df_customer_value['n_order_dis'] = df_customer_value['n_success'].apply(lambda x: 'more than 10' if x>=10 else str(x))

# %%
df_customer_value.head(2)
# Out:
#    customer_id  n_total  n_failed  n_success  s_money  s_discount  n_days  \
# 0       100001        1         0        1.0     7.42        2.06     1.0
# 1       100003        6         0        6.0    60.95        2.56     6.0
#
#    n_months  n_promotion  success_rate  promotion_rate  discount_rate  \
# 0       1.0          1.0           1.0        1.000000       0.277628
# 1       6.0          1.0           1.0        0.166667       0.042002
#
#   n_order_dis
# 0         1.0
# 1         6.0

# %%
df_n_dis = df_customer_value.groupby('n_order_dis').agg(total_cus = ('customer_id', 'count')).reset_index()

# %%
df_n_dis.head(12)
# Out:
#      n_order_dis  total_cus
# 0            0.0      13701
# 1            1.0      87921
# 2            2.0      12902
# 3            3.0       3145
# 4            4.0       1017
# 5            5.0        380
# 6            6.0        168
# 7            7.0         92
# 8            8.0         47
# 9            9.0         30
# 10  more than 10         74

# %%
plt.figure(figsize=(12,8))
plt.barh(
    df_n_dis['n_order_dis']
    , df_n_dis['total_cus']
    ,color = 'cornflowerblue'
    , alpha = 0.7
)
for index, value in enumerate(df_n_dis['total_cus']):
    plt.text(value, index, str(value))
plt.title('#Customer by each group')

plt.show()

# %%
df_customer_value.count()
# Out:
# customer_id       119477
# n_total           119477
# n_failed          119477
# n_success         119477
# s_money           119477
# s_discount        119477
# n_days            119477
# n_months          119477
# n_promotion       119477
# success_rate      119477
# promotion_rate    105776
# discount_rate     105776
# n_order_dis       119477
# dtype: int64

# %%
# if customer buy at a same time => not usual
# if customer buy day by day => usual

# %%
df_customer_value.sort_values(by='n_success', ascending=False).head(20)
# Out:
#         customer_id  n_total  n_failed  n_success  s_money  s_discount  \
# 2686         102948      260         0      260.0  1291.25        3.38
# 48948        153588      108         1      107.0   434.59        0.00
# 10604        111644      104         0      104.0   581.70       18.52
# 15783        117362      104         1      103.0   744.86        8.62
# 16687        118349       83         3       80.0   344.56        4.21
# 20907        122962       77         1       76.0   447.00        1.86
# 72718        179471       69         1       68.0   375.91        7.14
# 62432        168132       69         3       66.0   249.03        0.00
# 111563       222641       51         0       51.0   240.84        2.31
# 53097        158089       53         2       51.0   245.14        1.69
# 115005       226527       49         0       49.0   339.56       12.79
# 15888        117475       49         1       48.0   297.40        2.56
# 48524        153124       49         3       46.0   337.88       27.02
# 7438         108162       44         1       43.0   272.12        6.72
# 7389         108110       43         2       41.0   184.65        1.24
# 29091        131905       39         1       38.0   242.70        0.00
# 115304       226886       37         0       37.0   186.01        1.90
# 15581        117140       36         0       36.0   150.73       13.11
# 7947         108729       34         0       34.0   163.40        0.00
# 2765         103035       34         0       34.0   318.70        0.00
#
#         n_days  n_months  n_promotion  success_rate  promotion_rate  \
# 2686     148.0      18.0          1.0      1.000000        0.003846
# 48948     77.0      14.0          0.0      0.990741        0.000000
# 10604     85.0      18.0          9.0      1.000000        0.086538
# 15783     79.0      15.0          6.0      0.990385        0.058252
# 16687     62.0      17.0          1.0      0.963855        0.012500
# 20907     45.0       9.0          3.0      0.987013        0.039474
# 72718     51.0       9.0          4.0      0.985507        0.058824
# 62432     59.0      14.0          0.0      0.956522        0.000000
# 111563    41.0      11.0          3.0      1.000000        0.058824
# 53097     40.0      14.0          2.0      0.962264        0.039216
# 115005    38.0       7.0          5.0      1.000000        0.102041
# 15888     30.0      13.0          1.0      0.979592        0.020833
# 48524     43.0      17.0          7.0      0.938776        0.152174
# 7438      38.0      14.0          2.0      0.977273        0.046512
# 7389      32.0      10.0          2.0      0.953488        0.048780
# 29091     35.0      18.0          0.0      0.974359        0.000000
# 115304    27.0       5.0          1.0      1.000000        0.027027
# 15581     31.0      15.0          5.0      1.000000        0.138889
# 7947      29.0       4.0          0.0      1.000000        0.000000
# 2765      24.0      10.0          0.0      1.000000        0.000000
#
#         discount_rate   n_order_dis
# 2686         0.002618  more than 10
# 48948        0.000000  more than 10
# 10604        0.031838  more than 10
# 15783        0.011573  more than 10
# 16687        0.012218  more than 10
# 20907        0.004161  more than 10
# 72718        0.018994  more than 10
# 62432        0.000000  more than 10
# 111563       0.009591  more than 10
# 53097        0.006894  more than 10
# 115005       0.037666  more than 10
# 15888        0.008608  more than 10
# 48524        0.079969  more than 10
# 7438         0.024695  more than 10
# 7389         0.006715  more than 10
# 29091        0.000000  more than 10
# 115304       0.010215  more than 10
# 15581        0.086977  more than 10
# 7947         0.000000  more than 10
# 2765         0.000000  more than 10

# %%
list_customer_massive = list(df_customer_value[df_customer_value['n_success'] > 30]['customer_id'].unique())

# %%
list_customer_massive
# Out:
# [np.int64(102948),
#  np.int64(103035),
#  np.int64(103347),
#  np.int64(108110),
#  np.int64(108162),
#  np.int64(108729),
#  np.int64(111644),
#  np.int64(114205),
#  np.int64(117140),
#  np.int64(117362),
#  np.int64(117475),
#  np.int64(118349),
#  np.int64(122962),
#  np.int64(131905),
#  np.int64(153124),
#  np.int64(153588),
#  np.int64(158089),
#  np.int64(168132),
#  np.int64(179471),
#  np.int64(222641),
#  np.int64(226527),
#  np.int64(226886)]

# %%
list_customer_massive_pivot = (
    df_join_all[df_join_all['customer_id'].isin(list_customer_massive) & (df_join_all['status_id'] == 1)]
    .pivot_table(index='year_month', columns='customer_id', values='ticket_id', aggfunc='count')
    .reset_index()
)

# %%
list_customer_massive_pivot.head(20)
# Out:
# customer_id year_month  102948  103035  103347  108110  108162  108729  \
# 0              2019-01     NaN     NaN     NaN     NaN     1.0     NaN
# 1              2019-02     NaN     NaN     NaN     NaN     1.0     NaN
# 2              2019-03     NaN     NaN     NaN     NaN     NaN     NaN
# 3              2019-04     NaN     3.0     NaN     NaN     1.0     NaN
# 4              2019-05     NaN     2.0     NaN     NaN     4.0     NaN
# 5              2019-06     NaN     NaN     NaN     NaN     2.0     NaN
# 6              2019-07     NaN     NaN     NaN     NaN     NaN     NaN
# 7              2019-08     NaN     3.0     NaN     NaN     NaN     NaN
# 8              2019-09     NaN     2.0     NaN     NaN     NaN     NaN
# 9              2019-10     NaN     4.0     NaN     NaN     NaN     NaN
# 10             2019-11     NaN     NaN     NaN     NaN     4.0     NaN
# 11             2019-12     NaN     1.0     NaN     NaN     7.0     NaN
# 12             2020-01     NaN     NaN     NaN     NaN    10.0     NaN
# 13             2020-02     NaN     1.0     NaN     NaN     3.0     NaN
# 14             2020-03     NaN     NaN     NaN     NaN     NaN     NaN
# 15             2020-07     NaN     NaN     NaN     NaN     NaN     NaN
# 16             2020-08     NaN     1.0     NaN     NaN     NaN     NaN
# 17             2020-09     NaN     NaN     NaN     NaN     NaN     NaN
# 18             2020-10     1.0     NaN     NaN     NaN     NaN     NaN
# 19             2020-11     NaN     NaN     NaN     NaN     NaN     NaN
#
# customer_id  111644  114205  117140  117362  117475  118349  122962  131905  \
# 0               NaN     1.0     NaN     NaN     NaN     NaN     NaN     NaN
# 1               NaN     2.0     NaN     NaN     NaN     NaN     NaN     NaN
# 2               NaN     1.0     NaN     NaN     NaN     NaN     NaN     NaN
# 3               NaN     NaN     NaN     NaN     NaN     NaN     NaN     3.0
# 4               NaN     NaN     1.0     NaN     NaN     1.0     NaN     2.0
# 5               NaN     2.0     1.0     NaN     1.0     NaN     NaN     1.0
# 6               NaN     3.0     NaN     NaN     NaN     NaN     NaN     NaN
# 7               NaN     6.0     NaN     NaN     NaN     NaN     NaN     1.0
# 8               NaN     2.0     NaN     NaN     NaN     NaN     NaN     2.0
# 9               1.0     3.0     NaN     NaN     NaN     NaN     NaN     1.0
# 10              NaN     NaN     NaN     NaN     NaN     NaN     NaN     1.0
# 11              NaN     1.0     NaN     NaN     NaN     4.0     NaN     1.0
# 12              NaN     2.0     NaN     1.0     NaN     4.0     NaN     NaN
# 13              NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 14              NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 15              NaN     NaN     1.0     NaN     1.0     NaN     NaN     NaN
# 16              NaN     NaN     1.0     NaN     NaN     NaN     NaN     NaN
# 17              NaN     NaN     NaN     1.0     1.0     NaN     NaN     1.0
# 18              1.0     NaN     2.0     NaN     1.0     NaN     NaN     1.0
# 19              3.0     1.0     4.0     NaN     NaN     NaN     NaN     NaN
#
# customer_id  153124  153588  158089  168132  179471  222641  226527  226886
# 0               NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 1               NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 2               NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 3               2.0     NaN     3.0     NaN     NaN     NaN     NaN     NaN
# 4               3.0     NaN     7.0     NaN     NaN     NaN     NaN     NaN
# 5               7.0     NaN     2.0     NaN     NaN     NaN     NaN     NaN
# 6               5.0     NaN     3.0     NaN     NaN     NaN     NaN     NaN
# 7               7.0     NaN     5.0     NaN     NaN     NaN     NaN     NaN
# 8               1.0     NaN     2.0     NaN     NaN     NaN     NaN     NaN
# 9               1.0     NaN     7.0     NaN     NaN     NaN     NaN     NaN
# 10              NaN     NaN     7.0     NaN     NaN     NaN     NaN     NaN
# 11              4.0     NaN     6.0     NaN     NaN     NaN     NaN     NaN
# 12              3.0     NaN     4.0     1.0     NaN     NaN     NaN     NaN
# 13              NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 14              1.0     NaN     1.0     NaN     NaN     NaN     NaN     NaN
# 15              3.0     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 16              NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 17              NaN     NaN     1.0     NaN     NaN     NaN     NaN     NaN
# 18              2.0     NaN     NaN     3.0     NaN     NaN     NaN     NaN
# 19              2.0     NaN     NaN     1.0     NaN     NaN     NaN     NaN

# %%
# Bar chart with collapse column
ax = list_customer_massive_pivot.plot(x = 'year_month', kind='bar', stacked=True, figsize=(15,6), width=0.8, alpha = 0.7)

ax.set_title('Massive customer trend')
ax.set_ylabel('Number of Tickets')

plt.legend(title='customer_id', bbox_to_anchor=(1.15, 1), loc='upper right')
plt.xticks(rotation=90)
ax.set_ylabel('Number of Tickets')

plt.show()

# %%
## no spam tickets

# %% [markdown]
# ## Massive promotion

# %%
df_customer_value.head(2)
# Out:
#    customer_id  n_total  n_failed  n_success  s_money  s_discount  n_days  \
# 0       100001        1         0        1.0     7.42        2.06     1.0
# 1       100003        6         0        6.0    60.95        2.56     6.0
#
#    n_months  n_promotion  success_rate  promotion_rate  discount_rate  \
# 0       1.0          1.0           1.0        1.000000       0.277628
# 1       6.0          1.0           1.0        0.166667       0.042002
#
#   n_order_dis
# 0         1.0
# 1         6.0

# %%
df_customer_value['n_promo_dis'] = df_customer_value['n_promotion'].apply(lambda x: 'more than 10' if x>=10 else str(x))

# %%
df_promo_dis = df_customer_value.groupby('n_promo_dis').agg(total_cus = ('customer_id', 'count')).reset_index()

# %%
df_promo_dis.head(11)
# Out:
#      n_promo_dis  total_cus
# 0            0.0      50498
# 1            1.0      61334
# 2            2.0       6264
# 3            3.0       1042
# 4            4.0        230
# 5            5.0         74
# 6            6.0         19
# 7            7.0         10
# 8            8.0          2
# 9            9.0          2
# 10  more than 10          2

# %%
plt.figure(figsize=(12,8))
plt.barh(
    df_promo_dis['n_promo_dis']
    , df_promo_dis['total_cus']
    ,color = 'cornflowerblue'
    , alpha = 0.7
)
for index, value in enumerate(df_promo_dis['total_cus']):
    plt.text(value, index, str(value))
plt.title('#Distribution of number ticktets by customer')

plt.show()

# %% [markdown]
# >> - 60% customers have joined the promotion ( 90% customers earn 1 time )
# >>> - Customer visits just one time
# >>> - the promotion is for one person(for new customers)

# %%
## what are the promotion that customer use ?

# %%
df_join_all.head(2)
# Out:
#                           ticket_id  customer_id paying_method  theater_name  \
# 0  4f5200dcdcf2396b8d50ff84bf423f32       100009  money in app          13.0
# 1  07abbaf28c772692f0367ad992bb3184       100493  bank account         180.0
#
#                       device_number  original_price  discount_value  \
# 0  244764a57dbdeb8fe9b164847ad55183            9.90            2.10
# 1  8fa83cf46284aafd6e5da6c96f7862b5            8.66            1.48
#
#    final_price                    time  status_id  campaign_id  \
# 0         7.80 2022-07-08 17:46:36.145          1        83330
# 1         7.18 2022-07-15 20:44:09.952          1        83330
#
#                movie_name usergender        dob    campaign_type  \
# 0  Thor: Love And Thunder       Male 1989-02-25  direct discount
# 1  Thor: Love And Thunder       Male 1991-06-09  direct discount
#
#         description error_group       model platform  age_days  age  month  \
# 0  Order successful     unknown  iPhone13,1   mobile     13223   36      7
# 1  Order successful     unknown     browser  website     12389   33      7
#
#   name_day  hour year_month os_version       type
# 0   Friday    17    2022-07        ios  promotion
# 1   Friday    20    2022-07    browser  promotion

# %%
# evaluate the promotion
df_type_group = (
    df_join_all[ (df_join_all['status_id'] == 1) & (df_join_all['type'] == 'promotion')]
    .groupby('campaign_type').agg(total = ('ticket_id', 'count'))
    .reset_index()
)

# %%
df_type_group
# Out:
#      campaign_type  total
# 0  direct discount  68449
# 1     reward point   3150
# 2          voucher   6924

# %%
# Calculate the promotion detail for each customer

# %%
df_n_success = (
    df_join_all[ (df_join_all['status_id'] == 1) & (df_join_all['type'] == 'promotion')]
    .groupby('customer_id')
    .agg(n_promotion = ('ticket_id', 'count'))
    .reset_index()
)

# %%
df_n_pivot = (
   df_join_all[ (df_join_all['status_id'] == 1) & (df_join_all['type'] == 'promotion')]
    .pivot_table(index='customer_id', columns='campaign_type', values='ticket_id', aggfunc='count')
    .reset_index()
)

# %%
df_n_join = (
    pd.merge(df_n_pivot, df_n_success, on='customer_id', how='inner')
    .groupby('n_promotion').agg(n_cus = ('customer_id', 'count'),
                                n_voucher = ('voucher', 'sum'),
                                n_d_discount = ('direct discount', 'sum'),
                                n_reward_point = ('reward point', 'sum')
    )

    .reset_index()
)

# %%
df_n_join.head(10)
# Out:
#    n_promotion  n_cus  n_voucher  n_d_discount  n_reward_point
# 0            1  61334     5358.0       53098.0          2878.0
# 1            2   6264     1091.0       11222.0           215.0
# 2            3   1042      293.0        2788.0            45.0
# 3            4    230       87.0         827.0             6.0
# 4            5     74       43.0         323.0             4.0
# 5            6     19       12.0         102.0             0.0
# 6            7     10       14.0          54.0             2.0
# 7            8      2        2.0          14.0             0.0
# 8            9      2        6.0          12.0             0.0
# 9           10      1        1.0           9.0             0.0

# %%
df_n_join['total'] = df_n_join.iloc[:, 2:].sum(axis=1)

# %%
df_n_join.head(10)
# Out:
#    n_promotion  n_cus  n_voucher  n_d_discount  n_reward_point    total
# 0            1  61334     5358.0       53098.0          2878.0  61334.0
# 1            2   6264     1091.0       11222.0           215.0  12528.0
# 2            3   1042      293.0        2788.0            45.0   3126.0
# 3            4    230       87.0         827.0             6.0    920.0
# 4            5     74       43.0         323.0             4.0    370.0
# 5            6     19       12.0         102.0             0.0    114.0
# 6            7     10       14.0          54.0             2.0     70.0
# 7            8      2        2.0          14.0             0.0     16.0
# 8            9      2        6.0          12.0             0.0     18.0
# 9           10      1        1.0           9.0             0.0     10.0

# %%
for i in df_n_join.columns[2:5]:
    df_n_join[i+'_pct'] = df_n_join[i]/df_n_join['total']

# %%
format_dict = {'total':'{:,.0f}', 'n_voucher_pct': '{:,.0%}', 'n_d_discount_pct': '{:,.0%}', 'n_reward_point_pct': '{:,.0%}'}
df_n_join.style.format(format_dict)
# Out:
# <style type="text/css">
# </style>
# <table id="T_02361" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_02361_level0_col0" class="col_heading level0 col0" >n_promotion</th>
#       <th id="T_02361_level0_col1" class="col_heading level0 col1" >n_cus</th>
#       <th id="T_02361_level0_col2" class="col_heading level0 col2" >n_voucher</th>
#       <th id="T_02361_level0_col3" class="col_heading level0 col3" >n_d_discount</th>
#       <th id="T_02361_level0_col4" class="col_heading level0 col4" >n_reward_point</th>
#       <th id="T_02361_level0_col5" class="col_heading level0 col5" >total</th>
#       <th id="T_02361_level0_col6" class="col_heading level0 col6" >n_voucher_pct</th>
#       <th id="T_02361_level0_col7" class="col_heading level0 col7" >n_d_discount_pct</th>
#       <th id="T_02361_level0_col8" class="col_heading level0 col8" >n_reward_point_pct</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_02361_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_02361_row0_col0" class="data row0 col0" >1</td>
#       <td id="T_02361_row0_col1" class="data row0 col1" >61334</td>
#       <td id="T_02361_row0_col2" class="data row0 col2" >5358.000000</td>
#       <td id="T_02361_row0_col3" class="data row0 col3" >53098.000000</td>
#       <td id="T_02361_row0_col4" class="data row0 col4" >2878.000000</td>
#       <td id="T_02361_row0_col5" class="data row0 col5" >61,334</td>
#       <td id="T_02361_row0_col6" class="data row0 col6" >9%</td>
#       <td id="T_02361_row0_col7" class="data row0 col7" >87%</td>
#       <td id="T_02361_row0_col8" class="data row0 col8" >5%</td>
#     </tr>
#     <tr>
#       <th id="T_02361_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_02361_row1_col0" class="data row1 col0" >2</td>
#       <td id="T_02361_row1_col1" class="data row1 col1" >6264</td>
#       <td id="T_02361_row1_col2" class="data row1 col2" >1091.000000</td>
#       <td id="T_02361_row1_col3" class="data row1 col3" >11222.000000</td>
#       <td id="T_02361_row1_col4" class="data row1 col4" >215.000000</td>
#       <td id="T_02361_row1_col5" class="data row1 col5" >12,528</td>
#       <td id="T_02361_row1_col6" class="data row1 col6" >9%</td>
#       <td id="T_02361_row1_col7" class="data row1 col7" >90%</td>
#       <td id="T_02361_row1_col8" class="data row1 col8" >2%</td>
#     </tr>
#     <tr>
#       <th id="T_02361_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_02361_row2_col0" class="data row2 col0" >3</td>
#       <td id="T_02361_row2_col1" class="data row2 col1" >1042</td>
#       <td id="T_02361_row2_col2" class="data row2 col2" >293.000000</td>
#       <td id="T_02361_row2_col3" class="data row2 col3" >2788.000000</td>
#       <td id="T_02361_row2_col4" class="data row2 col4" >45.000000</td>
#       <td id="T_02361_row2_col5" class="data row2 col5" >3,126</td>
#       <td id="T_02361_row2_col6" class="data row2 col6" >9%</td>
#       <td id="T_02361_row2_col7" class="data row2 col7" >89%</td>
#       <td id="T_02361_row2_col8" class="data row2 col8" >1%</td>
#     </tr>
#     <tr>
#       <th id="T_02361_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_02361_row3_col0" class="data row3 col0" >4</td>
#       <td id="T_02361_row3_col1" class="data row3 col1" >230</td>
#       <td id="T_02361_row3_col2" class="data row3 col2" >87.000000</td>
#       <td id="T_02361_row3_col3" class="data row3 col3" >827.000000</td>
#       <td id="T_02361_row3_col4" class="data row3 col4" >6.000000</td>
#       <td id="T_02361_row3_col5" class="data row3 col5" >920</td>
#       <td id="T_02361_row3_col6" class="data row3 col6" >9%</td>
#       <td id="T_02361_row3_col7" class="data row3 col7" >90%</td>
#       <td id="T_02361_row3_col8" class="data row3 col8" >1%</td>
#     </tr>
#     <tr>
#       <th id="T_02361_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_02361_row4_col0" class="data row4 col0" >5</td>
#       <td id="T_02361_row4_col1" class="data row4 col1" >74</td>
#       <td id="T_02361_row4_col2" class="data row4 col2" >43.000000</td>
#       <td id="T_02361_row4_col3" class="data row4 col3" >323.000000</td>
#       <td id="T_02361_row4_col4" class="data row4 col4" >4.000000</td>
#       <td id="T_02361_row4_col5" class="data row4 col5" >370</td>
#       <td id="T_02361_row4_col6" class="data row4 col6" >12%</td>
#       <td id="T_02361_row4_col7" class="data row4 col7" >87%</td>
#       <td id="T_02361_row4_col8" class="data row4 col8" >1%</td>
#     </tr>
#     <tr>
#       <th id="T_02361_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_02361_row5_col0" class="data row5 col0" >6</td>
#       <td id="T_02361_row5_col1" class="data row5 col1" >19</td>
#       <td id="T_02361_row5_col2" class="data row5 col2" >12.000000</td>
#       <td id="T_02361_row5_col3" class="data row5 col3" >102.000000</td>
#       <td id="T_02361_row5_col4" class="data row5 col4" >0.000000</td>
#       <td id="T_02361_row5_col5" class="data row5 col5" >114</td>
#       <td id="T_02361_row5_col6" class="data row5 col6" >11%</td>
#       <td id="T_02361_row5_col7" class="data row5 col7" >89%</td>
#       <td id="T_02361_row5_col8" class="data row5 col8" >0%</td>
#     </tr>
#     <tr>
#       <th id="T_02361_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_02361_row6_col0" class="data row6 col0" >7</td>
#       <td id="T_02361_row6_col1" class="data row6 col1" >10</td>
#       <td id="T_02361_row6_col2" class="data row6 col2" >14.000000</td>
#       <td id="T_02361_row6_col3" class="data row6 col3" >54.000000</td>
#       <td id="T_02361_row6_col4" class="data row6 col4" >2.000000</td>
#       <td id="T_02361_row6_col5" class="data row6 col5" >70</td>
#       <td id="T_02361_row6_col6" class="data row6 col6" >20%</td>
#       <td id="T_02361_row6_col7" class="data row6 col7" >77%</td>
#       <td id="T_02361_row6_col8" class="data row6 col8" >3%</td>
#     </tr>
#     <tr>
#       <th id="T_02361_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_02361_row7_col0" class="data row7 col0" >8</td>
#       <td id="T_02361_row7_col1" class="data row7 col1" >2</td>
#       <td id="T_02361_row7_col2" class="data row7 col2" >2.000000</td>
#       <td id="T_02361_row7_col3" class="data row7 col3" >14.000000</td>
#       <td id="T_02361_row7_col4" class="data row7 col4" >0.000000</td>
#       <td id="T_02361_row7_col5" class="data row7 col5" >16</td>
#       <td id="T_02361_row7_col6" class="data row7 col6" >12%</td>
#       <td id="T_02361_row7_col7" class="data row7 col7" >88%</td>
#       <td id="T_02361_row7_col8" class="data row7 col8" >0%</td>
#     </tr>
#     <tr>
#       <th id="T_02361_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_02361_row8_col0" class="data row8 col0" >9</td>
#       <td id="T_02361_row8_col1" class="data row8 col1" >2</td>
#       <td id="T_02361_row8_col2" class="data row8 col2" >6.000000</td>
#       <td id="T_02361_row8_col3" class="data row8 col3" >12.000000</td>
#       <td id="T_02361_row8_col4" class="data row8 col4" >0.000000</td>
#       <td id="T_02361_row8_col5" class="data row8 col5" >18</td>
#       <td id="T_02361_row8_col6" class="data row8 col6" >33%</td>
#       <td id="T_02361_row8_col7" class="data row8 col7" >67%</td>
#       <td id="T_02361_row8_col8" class="data row8 col8" >0%</td>
#     </tr>
#     <tr>
#       <th id="T_02361_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_02361_row9_col0" class="data row9 col0" >10</td>
#       <td id="T_02361_row9_col1" class="data row9 col1" >1</td>
#       <td id="T_02361_row9_col2" class="data row9 col2" >1.000000</td>
#       <td id="T_02361_row9_col3" class="data row9 col3" >9.000000</td>
#       <td id="T_02361_row9_col4" class="data row9 col4" >0.000000</td>
#       <td id="T_02361_row9_col5" class="data row9 col5" >10</td>
#       <td id="T_02361_row9_col6" class="data row9 col6" >10%</td>
#       <td id="T_02361_row9_col7" class="data row9 col7" >90%</td>
#       <td id="T_02361_row9_col8" class="data row9 col8" >0%</td>
#     </tr>
#     <tr>
#       <th id="T_02361_

# %%
# heat map for table :
(
    df_n_join
    .drop(columns = ['n_voucher'	,'n_d_discount'	,'n_reward_point'])
    .style
    .format(format_dict)
    .background_gradient(subset = ['n_voucher_pct',	'n_d_discount_pct',	'n_reward_point_pct'],cmap='PuBu')
    .background_gradient(subset = ['total'], cmap='YlOrBr')
)
# Out:
# <style type="text/css">
# #T_c05d6_row0_col2 {
#   background-color: #662506;
#   color: #f1f1f1;
# }
# #T_c05d6_row0_col3, #T_c05d6_row1_col3, #T_c05d6_row5_col5, #T_c05d6_row7_col5, #T_c05d6_row8_col5, #T_c05d6_row9_col5, #T_c05d6_row10_col4, #T_c05d6_row10_col5 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_c05d6_row0_col4 {
#   background-color: #034267;
#   color: #f1f1f1;
# }
# #T_c05d6_row0_col5, #T_c05d6_row3_col4, #T_c05d6_row9_col4, #T_c05d6_row10_col3 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_c05d6_row1_col2 {
#   background-color: #feeaa1;
#   color: #000000;
# }
# #T_c05d6_row1_col4, #T_c05d6_row5_col4 {
#   background-color: #02395a;
#   color: #f1f1f1;
# }
# #T_c05d6_row1_col5 {
#   background-color: #a9bfdc;
#   color: #000000;
# }
# #T_c05d6_row2_col2 {
#   background-color: #fffcd4;
#   color: #000000;
# }
# #T_c05d6_row2_col3 {
#   background-color: #fef6fb;
#   color: #000000;
# }
# #T_c05d6_row2_col4 {
#   background-color: #023a5b;
#   color: #f1f1f1;
# }
# #T_c05d6_row2_col5 {
#   background-color: #bdc8e1;
#   color: #000000;
# }
# #T_c05d6_row3_col2 {
#   background-color: #fffee1;
#   color: #000000;
# }
# #T_c05d6_row3_col3 {
#   background-color: #fef6fa;
#   color: #000000;
# }
# #T_c05d6_row3_col5 {
#   background-color: #e9e5f1;
#   color: #000000;
# }
# #T_c05d6_row4_col2 {
#   background-color: #ffffe4;
#   color: #000000;
# }
# #T_c05d6_row4_col3 {
#   background-color: #faf3f9;
#   color: #000000;
# }
# #T_c05d6_row4_col4, #T_c05d6_row7_col4 {
#   background-color: #023f64;
#   color: #f1f1f1;
# }
# #T_c05d6_row4_col5 {
#   background-color: #d5d5e8;
#   color: #000000;
# }
# #T_c05d6_row5_col2, #T_c05d6_row6_col2, #T_c05d6_row7_col2, #T_c05d6_row8_col2, #T_c05d6_row9_col2, #T_c05d6_row10_col2 {
#   background-color: #ffffe5;
#   color: #000000;
# }
# #T_c05d6_row5_col3 {
#   background-color: #fcf4fa;
#   color: #000000;
# }
# #T_c05d6_row6_col3 {
#   background-color: #ede7f2;
#   color: #000000;
# }
# #T_c05d6_row6_col4 {
#   background-color: #045d92;
#   color: #f1f1f1;
# }
# #T_c05d6_row6_col5 {
#   background-color: #3f93c2;
#   color: #f1f1f1;
# }
# #T_c05d6_row7_col3 {
#   background-color: #f9f2f8;
#   color: #000000;
# }
# #T_c05d6_row8_col3 {
#   background-color: #c9cee4;
#   color: #000000;
# }
# #T_c05d6_row8_col4 {
#   background-color: #0872b1;
#   color: #f1f1f1;
# }
# #T_c05d6_row9_col3 {
#   background-color: #fdf5fa;
#   color: #000000;
# }
# </style>
# <table id="T_c05d6" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_c05d6_level0_col0" class="col_heading level0 col0" >n_promotion</th>
#       <th id="T_c05d6_level0_col1" class="col_heading level0 col1" >n_cus</th>
#       <th id="T_c05d6_level0_col2" class="col_heading level0 col2" >total</th>
#       <th id="T_c05d6_level0_col3" class="col_heading level0 col3" >n_voucher_pct</th>
#       <th id="T_c05d6_level0_col4" class="col_heading level0 col4" >n_d_discount_pct</th>
#       <th id="T_c05d6_level0_col5" class="col_heading level0 col5" >n_reward_point_pct</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c05d6_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_c05d6_row0_col0" class="data row0 col0" >1</td>
#       <td id="T_c05d6_row0_col1" class="data row0 col1" >61334</td>
#       <td id="T_c05d6_row0_col2" class="data row0 col2" >61,334</td>
#       <td id="T_c05d6_row0_col3" class="data row0 col3" >9%</td>
#       <td id="T_c05d6_row0_col4" class="data row0 col4" >87%</td>
#       <td id="T_c05d6_row0_col5" class="data row0 col5" >5%</td>
#     </tr>
#     <tr>
#       <th id="T_c05d6_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_c05d6_row1_col0" class="data row1 col0" >2</td>
#       <td id="T_c05d6_row1_col1" class="data row1 col1" >6264</td>
#       <td id="T_c05d6_row1_col2" class="data row1 col2" >12,528</td>
#       <td id="T_c05d6_row1_col3" class="data row1 col3" >9%</td>
#       <td id="T_c05d6_row1_col4" class="data row1 col4" >90%</td>
#       <td id="T_c05d6_row1_col5" class="data row1 col5" >2%</td>
#     </tr>
#     <tr>
#       <th id="T_c05d6_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_c05d6_row2_col0" class="data row2 col0" >3</td>
#       <td id="T_c05d6_row2_col1" class="data row2 col1" >1042</td>
#       <td id="T_c05d6_row2_col2" class="data row2 col2" >3,126</td>
#       <td id="T_c05d6_row2_col3" class="data row2 col3" >9%</td>
#       <td id="T_c05d6_row2_col4" class="data row2 col4" >89%</td>
#       <td id="T_c05d6_row2_col5" class="data row2 col5" >1%</td>
#     </tr>
#     <tr>
#       <th id="T_c05d6_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_c05d6_row3_col0" class="data row3 col0" >4</td>
#       <td id="T_c05d6_row3_col1" class="data row3 col1" >230</td>
#       <td id="T_c05d6_row3_col2" class="data row3 col2" >920</td>
#       <td id="T_c05d6_row3_col3" class="data row3 col3" >9%</td>
#       <td id="T_c05d6_row3_col4" class="data row3 col4" >90%</td>
#       <td id="T_c05d6_row3_col5" class="data row3 col5" >1%</td>
#     </tr>
#     <tr>
#       <th id="T_c05d6_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_c05d6_row4_col0" class="data row4 col0" >5</td>
#       <td id="T_c05d6_row4_col1" class="data row4 col1" >74</td>
#       <td id="T_c05d6_row4_col2" class="data row4 col2" >370</td>
#       <td id="T_c05d6_row4_col3" class="data row4 col3" >12%</td>
#       <td id="T_c05d6_row4_col4" class="data row4 col4" >87%</td>
#       <td id="T_c05d6_row4_col5" class="data row4 col5" >1%</td>
#     </tr>
#     <tr>
#       <th id="T_c05d6_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_c05d6_row5_col0" class="data row5 col0" >6</td>
#       <td id="T_c05d6_row5_col1" class="data row5 col1" >19</td>
#       <td id="T_c05d6_row5_col2" class="data row5 col2" >114</td>
#       <td id="T_c05d6_row5_col3" class="data row5 col3" >11%</td>
#       <td id="T_c05d6_row5_col4" class="data row5 col4" >89%</td>
#       <td id="T_c05d6_row5_col5" class="data row5 col5" >0%</td>
#     </tr>
#     <tr>
#       <th id="T_c05d6_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_c05d6_row6_col0" class="data row6 col0" >7</td>
#       <td id="T_c05d6_row6_col1" class="data row6 col1" >10</td>
#       <td id="T_c05d6_row6_col2" class="data row6 col2" >70</td>
#       <td id="T_c05d6_row6_col3" class="data row6 col3" >20%</td>
#       <td id="T_c05d6_row6_col4" class="data row6 col4" >77%</td>
#       <td id="T_c05d6_row6_col5" class="data row6 col5" >3%</td>
#     </tr>
#     <tr>
#       <th id="T_c05d6_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_c05d6_row7_col0" class="data row7 col0" >8</td>
#       <td id="T_c05d6_row7_col1" class="data row7 col1" >2</td>
#       <td id="T_c05d6_row7_col2" class="data row7 col2" >16</td>
#       <td id="T_c05d6_row7_col3" class="data row7 col3" >12%</td>
#       <td id="T_c05d6_row7_col4" class="data row7 col4" >88%</td>
#       <td id="T_c05d6_row7_col5" class="data row7 col5" >0%</td>
#     </tr>
#     <tr>
#       <th id="T_c05d6_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_c05d6_row8_col0" class="data row8 col0" >9</td>
#       <td id="T_c05d6_row8_col1" class="data row8 col1" >2</td>
#       <td id="T_c05d6_row8_col2" class="data row8 col2" >18</td>
#       <td id="T_c05d6_row8_col3" class="data row8 col3" >33%</td>
#       <td id="T_c05d6_row8_col4" class="data row8 col4" >67%</td>
#       <td id="T_c05d6_row8_col5" class="data row8 col5" >0%</td>
#     </tr>
#     <tr>
#       <th id="T_c05d6_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_c05d6_row9_col0" class="data row9 col0" >10</td>
#       <td id="T_c05d6_row9_col1" class="data row9 col1" >1</td>
#       <td id="T_c05d6_row9_col2" class="data row9 col2" >10</td>
#       <td id="T_c05d6_row9_col3" class="data row9 col3" >10%</td>
#       <td id="T_c05d6_row9_col4" class="data row9 col4" >90%</td>
#       <td id="T_c05d6_row9_col5" class="data row9 col5" >0%</td>
#     </tr>
#     <tr>
#       <th id="T_c05d6_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_c05d6_row10_col0" class="data row10 col0" >17</td>
#       <td id="T_c05d6_row10_col1" class="data row10 col1" >1</td>

# %% [markdown]
# > **Notes:**
# >> - 90% customers choose direct discount

# %% [markdown]
# ## 3.5 Customer retention - Cohort Analysis

# %%
#1 Base on the time change the customer : first time payment , buying , dowload app
from operator import attrgetter
import matplotlib.colors as mcolors
import seaborn as sns

# %%
#calculate cohort (first_month , current_month, subsequent_month)
df_selected_time = df_join_all[ (df_join_all['time'] < '2020-01-01') & (df_join_all['status_id'] == 1)]
df_selected_time['first_month'] = df_selected_time.groupby('customer_id')['time'].transform('min').dt.to_period('M')
df_selected_time['current_month'] = df_selected_time['time'].dt.to_period('M')
df_selected_time['subsequent_month'] = (df_selected_time['current_month'] - df_selected_time['first_month']).apply(attrgetter('n'))
# Out:
# <ipython-input-154-97eb6340eebc>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_selected_time['first_month'] = df_selected_time.groupby('customer_id')['time'].transform('min').dt.to_period('M')
# <ipython-input-154-97eb6340eebc>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_selected_time['current_month'] = df_selected_time['time'].dt.to_period('M')
# <ipython-input-154-97eb6340eebc>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_selected_time['subsequent_month'] = (df_selected_time['current_month'] - df_selected_time['first_month']).apply(attrgetter('n'))

# %%
df_selected_time.head(5)
# Out:
#                               ticket_id  customer_id paying_method  \
# 11327  9e3e753f70aede1c6dcc577ce563eef1       100009   credit card
# 11328  74a0ac9b7c60d2e7d3664686c3342c00       101892  money in app
# 11329  4a653fb01188cfaefe7e3731de2648de       105574   credit card
# 11332  f075d68aa14bc424e3d9ca7904f900a5       111681   credit card
# 11333  747efd023e43617ca96e127c8af625b8       116896  money in app
#
#        theater_name                     device_number  original_price  \
# 11327          74.0  3cac5d2e2eb76525aecea5c2ab46b3d9            9.07
# 11328          79.0  fe9a5c91e224f005a8be1c62923548d8            9.07
# 11329          43.0  99b47df3cdeecb3dec4da6c18b916dd0            9.07
# 11332         123.0  a43fb711603d5f2be7001397d280e413            8.66
# 11333          72.0  ac219f148fe5a9653b48ce64b41625b7            6.19
#
#        discount_value  final_price                    time  status_id  \
# 11327            2.56         6.51 2019-11-09 16:19:41.008          1
# 11328            2.56         6.51 2019-11-16 16:35:02.953          1
# 11329            2.56         6.51 2019-11-09 18:10:13.461          1
# 11332            2.10         6.56 2019-11-16 22:02:42.851          1
# 11333            0.00         6.19 2019-11-13 17:32:32.892          1
#
#        campaign_id    movie_name  usergender        dob    campaign_type  \
# 11327        25680  Doctor Sleep        Male 1989-02-25  direct discount
# 11328        25690  Doctor Sleep      Female 1986-10-19  direct discount
# 11329        25680  Doctor Sleep        Male 1935-01-01  direct discount
# 11332        25690  Doctor Sleep  Not verify 1970-01-01  direct discount
# 11333            0  Doctor Sleep        Male 1990-08-30          unknown
#
#             description error_group             model platform  age_days  age  \
# 11327  Order successful     unknown        iPhone10,2   mobile     13223   36
# 11328  Order successful     unknown  Samsung SM-N935F   mobile     14083   38
# 11329  Order successful     unknown         iPhone9,2   mobile     33002   90
# 11332  Order successful     unknown      HTC HTC_U-3u   mobile     20218   55
# 11333  Order successful     unknown    OnePlus HD1900   mobile     12672   34
#
#        month   name_day  hour year_month       os_version           type  \
# 11327     11   Saturday    16    2019-11              ios      promotion
# 11328     11   Saturday    16    2019-11  android & other      promotion
# 11329     11   Saturday    18    2019-11              ios      promotion
# 11332     11   Saturday    22    2019-11  android & other      promotion
# 11333     11  Wednesday    17    2019-11  android & other  non promotion
#
#       first_month current_month  subsequent_month
# 11327     2019-04       2019-11                 7
# 11328     2019-08       2019-11                 3
# 11329     2019-11       2019-11                 0
# 11332     2019-11       2019-11                 0
# 11333     2019-11       2019-11                 0

# %%
df_selected_time.head(5)
# Out:
#                               ticket_id  customer_id paying_method  \
# 11327  9e3e753f70aede1c6dcc577ce563eef1       100009   credit card
# 11328  74a0ac9b7c60d2e7d3664686c3342c00       101892  money in app
# 11329  4a653fb01188cfaefe7e3731de2648de       105574   credit card
# 11332  f075d68aa14bc424e3d9ca7904f900a5       111681   credit card
# 11333  747efd023e43617ca96e127c8af625b8       116896  money in app
#
#        theater_name                     device_number  original_price  \
# 11327          74.0  3cac5d2e2eb76525aecea5c2ab46b3d9            9.07
# 11328          79.0  fe9a5c91e224f005a8be1c62923548d8            9.07
# 11329          43.0  99b47df3cdeecb3dec4da6c18b916dd0            9.07
# 11332         123.0  a43fb711603d5f2be7001397d280e413            8.66
# 11333          72.0  ac219f148fe5a9653b48ce64b41625b7            6.19
#
#        discount_value  final_price                    time  status_id  \
# 11327            2.56         6.51 2019-11-09 16:19:41.008          1
# 11328            2.56         6.51 2019-11-16 16:35:02.953          1
# 11329            2.56         6.51 2019-11-09 18:10:13.461          1
# 11332            2.10         6.56 2019-11-16 22:02:42.851          1
# 11333            0.00         6.19 2019-11-13 17:32:32.892          1
#
#        campaign_id    movie_name  usergender        dob    campaign_type  \
# 11327        25680  Doctor Sleep        Male 1989-02-25  direct discount
# 11328        25690  Doctor Sleep      Female 1986-10-19  direct discount
# 11329        25680  Doctor Sleep        Male 1935-01-01  direct discount
# 11332        25690  Doctor Sleep  Not verify 1970-01-01  direct discount
# 11333            0  Doctor Sleep        Male 1990-08-30          unknown
#
#             description error_group             model platform  age_days  age  \
# 11327  Order successful     unknown        iPhone10,2   mobile     13223   36
# 11328  Order successful     unknown  Samsung SM-N935F   mobile     14083   38
# 11329  Order successful     unknown         iPhone9,2   mobile     33002   90
# 11332  Order successful     unknown      HTC HTC_U-3u   mobile     20218   55
# 11333  Order successful     unknown    OnePlus HD1900   mobile     12672   34
#
#        month   name_day  hour year_month       os_version           type  \
# 11327     11   Saturday    16    2019-11              ios      promotion
# 11328     11   Saturday    16    2019-11  android & other      promotion
# 11329     11   Saturday    18    2019-11              ios      promotion
# 11332     11   Saturday    22    2019-11  android & other      promotion
# 11333     11  Wednesday    17    2019-11  android & other  non promotion
#
#       first_month current_month  subsequent_month
# 11327     2019-04       2019-11                 7
# 11328     2019-08       2019-11                 3
# 11329     2019-11       2019-11                 0
# 11332     2019-11       2019-11                 0
# 11333     2019-11       2019-11                 0

# %%
## step 2 : group by cohort
df_cohor = df_selected_time.groupby(['first_month','current_month', 'subsequent_month']) \
    .agg(n_customers = ('customer_id', 'nunique')) \
    .reset_index()

# %%
df_cohor.head(10) #PIVOT the result
# Out:
#   first_month current_month  subsequent_month  n_customers
# 0     2019-01       2019-01                 0         1348
# 1     2019-01       2019-02                 1           50
# 2     2019-01       2019-03                 2           35
# 3     2019-01       2019-04                 3           26
# 4     2019-01       2019-05                 4           25
# 5     2019-01       2019-06                 5           33
# 6     2019-01       2019-07                 6           36
# 7     2019-01       2019-08                 7           29
# 8     2019-01       2019-09                 8           18
# 9     2019-01       2019-10                 9           35

# %%
df_cohort_pivot = df_cohor.pivot_table(index='first_month', columns='subsequent_month', values='n_customers')

# %%
df_cohort_pivot.head(10)
# Out:
# subsequent_month      0      1      2      3      4      5     6     7     8   \
# first_month
# 2019-01           1348.0   50.0   35.0   26.0   25.0   33.0  36.0  29.0  18.0
# 2019-02           1293.0   58.0   88.0   64.0   78.0   50.0  58.0  30.0  46.0
# 2019-03            745.0   51.0   48.0   49.0   33.0   33.0  30.0  34.0  23.0
# 2019-04           2922.0  101.0  103.0   87.0   92.0   66.0  96.0  63.0  42.0
# 2019-05           3226.0  145.0  118.0  129.0   90.0   93.0  90.0  62.0   NaN
# 2019-06           3062.0  131.0  151.0   98.0  133.0  114.0  63.0   NaN   NaN
# 2019-07           2611.0  121.0   79.0   99.0   78.0   40.0   NaN   NaN   NaN
# 2019-08           3735.0  112.0  155.0  106.0   64.0    NaN   NaN   NaN   NaN
# 2019-09           2169.0  117.0   67.0   39.0    NaN    NaN   NaN   NaN   NaN
# 2019-10           3364.0  137.0   71.0    NaN    NaN    NaN   NaN   NaN   NaN
#
# subsequent_month    9     10    11
# first_month
# 2019-01           35.0  21.0  20.0
# 2019-02           29.0  35.0   NaN
# 2019-03           14.0   NaN   NaN
# 2019-04            NaN   NaN   NaN
# 2019-05            NaN   NaN   NaN
# 2019-06            NaN   NaN   NaN
# 2019-07            NaN   NaN   NaN
# 2019-08            NaN   NaN   NaN
# 2019-09            NaN   NaN   NaN
# 2019-10            NaN   NaN   NaN

# %%
cohort_size = df_cohort_pivot.iloc[:,0]
retention_matrix = df_cohort_pivot.divide(cohort_size, axis=0)

# %%
cohort_size
# Out:
# first_month
# 2019-01    1348.0
# 2019-02    1293.0
# 2019-03     745.0
# 2019-04    2922.0
# 2019-05    3226.0
# 2019-06    3062.0
# 2019-07    2611.0
# 2019-08    3735.0
# 2019-09    2169.0
# 2019-10    3364.0
# 2019-11    1522.0
# 2019-12     834.0
# Freq: M, Name: 0, dtype: float64

# %%
retention_matrix
# Out:
# subsequent_month   0         1         2         3         4         5   \
# first_month
# 2019-01           1.0  0.037092  0.025964  0.019288  0.018546  0.024481
# 2019-02           1.0  0.044857  0.068059  0.049497  0.060325  0.038670
# 2019-03           1.0  0.068456  0.064430  0.065772  0.044295  0.044295
# 2019-04           1.0  0.034565  0.035250  0.029774  0.031485  0.022587
# 2019-05           1.0  0.044947  0.036578  0.039988  0.027898  0.028828
# 2019-06           1.0  0.042782  0.049314  0.032005  0.043436  0.037231
# 2019-07           1.0  0.046342  0.030257  0.037917  0.029874  0.015320
# 2019-08           1.0  0.029987  0.041499  0.028380  0.017135       NaN
# 2019-09           1.0  0.053942  0.030890  0.017981       NaN       NaN
# 2019-10           1.0  0.040725  0.021106       NaN       NaN       NaN
# 2019-11           1.0  0.031537       NaN       NaN       NaN       NaN
# 2019-12           1.0       NaN       NaN       NaN       NaN       NaN
#
# subsequent_month        6         7         8         9         10        11
# first_month
# 2019-01           0.026706  0.021513  0.013353  0.025964  0.015579  0.014837
# 2019-02           0.044857  0.023202  0.035576  0.022428  0.027069       NaN
# 2019-03           0.040268  0.045638  0.030872  0.018792       NaN       NaN
# 2019-04           0.032854  0.021561  0.014374       NaN       NaN       NaN
# 2019-05           0.027898  0.019219       NaN       NaN       NaN       NaN
# 2019-06           0.020575       NaN       NaN       NaN       NaN       NaN
# 2019-07                NaN       NaN       NaN       NaN       NaN       NaN
# 2019-08                NaN       NaN       NaN       NaN       NaN       NaN
# 2019-09                NaN       NaN       NaN       NaN       NaN       NaN
# 2019-10                NaN       NaN       NaN       NaN       NaN       NaN
# 2019-11                NaN       NaN       NaN       NaN       NaN       NaN
# 2019-12                NaN       NaN       NaN       NaN       NaN       NaN

# %%
with sns.axes_style("white"):
    fig, ax = plt.subplots(1, 2, figsize=(12, 8), sharey=True, gridspec_kw={'width_ratios': [1, 11]})

    #retention matrix
    sns.heatmap(retention_matrix, mask=retention_matrix.isnull(), annot=True, fmt='.0%', cmap='YlGnBu', ax=ax[1])
    ax[1].set_title('Monthly Cohorts: User Retention 2019', fontsize=16)
    ax[1].set(xlabel='subsequent months',ylabel='')
    #cohort size
    cohort_size_df = pd.DataFrame(cohort_size).rename(columns={0: 'original customers'})
    white_cmap = mcolors.ListedColormap(['White'])
    sns.heatmap(cohort_size_df, annot=True, cbar=False, cmap=white_cmap, fmt='g', ax=ax[0])
    fig.tight_layout()

# %%
#calculate cohort (first_month , current_month, subsequent_month)
df_selected_time = df_join_all[ (df_join_all['time'] > '2022-01-01') & (df_join_all['status_id'] == 1)]
df_selected_time['first_month'] = df_selected_time.groupby('customer_id')['time'].transform('min').dt.to_period('M')
df_selected_time['current_month'] = df_selected_time['time'].dt.to_period('M')
df_selected_time['subsequent_month'] = (df_selected_time['current_month'] - df_selected_time['first_month']).apply(attrgetter('n'))
# Out:
# <ipython-input-165-1b5e1cc2cff0>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_selected_time['first_month'] = df_selected_time.groupby('customer_id')['time'].transform('min').dt.to_period('M')
# <ipython-input-165-1b5e1cc2cff0>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_selected_time['current_month'] = df_selected_time['time'].dt.to_period('M')
# <ipython-input-165-1b5e1cc2cff0>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_selected_time['subsequent_month'] = (df_selected_time['current_month'] - df_selected_time['first_month']).apply(attrgetter('n'))

# %%
## step 2 : group by cohort
df_cohor = df_selected_time.groupby(['first_month','current_month', 'subsequent_month']) \
    .agg(n_customers = ('customer_id', 'nunique')) \
    .reset_index()

df_cohort_pivot = df_cohor.pivot_table(index='first_month', columns='subsequent_month', values='n_customers')

cohort_size = df_cohort_pivot.iloc[:,0]
retention_matrix = df_cohort_pivot.divide(cohort_size, axis=0)

# %%
with sns.axes_style("white"):
    fig, ax = plt.subplots(1, 2, figsize=(12, 8), sharey=True, gridspec_kw={'width_ratios': [1, 11]})

    #retention matrix
    sns.heatmap(retention_matrix, mask=retention_matrix.isnull(), annot=True, fmt='.0%', cmap='YlGnBu', ax=ax[1])
    ax[1].set_title('Monthly Cohorts: User Retention 2022', fontsize=16)
    ax[1].set(xlabel='subsequent months',ylabel='')
    #cohort size
    cohort_size_df = pd.DataFrame(cohort_size).rename(columns={0: 'original customers'})
    white_cmap = mcolors.ListedColormap(['White'])
    sns.heatmap(cohort_size_df, annot=True, cbar=False, cmap=white_cmap, fmt='g', ax=ax[0])
    fig.tight_layout()

# %% [markdown]
# Both 2019 and 2022 does not change , mostly because of covid
# => low retention

# %% [markdown]
# ## Compare : Retention of promotion customers &  organic customers

# %%
# By payment method
df_pie_promo = (
    df_join_all[(df_join_all['status_id'] == 1) & (df_join_all['time'] > '2022-01-01')]
    .groupby('type')
    .agg(total_ticket = ('customer_id', 'nunique'))
    .sort_values(by='total_ticket', ascending=True).reset_index()
    )

# %%
df_pie_promo
# Out:
#             type  total_ticket
# 0  non promotion         27672
# 1      promotion         47507

# %%
#pie
plt.figure(figsize=(6,3))
plt.pie(df_pie_promo['total_ticket'], labels=df_pie_promo['type'], colors=['cornflowerblue', 'tomato'], autopct='%1.0f%%', startangle=90)
plt.title('Percentage by type')
plt.show()

# %%
# Compare the different between promotion and organic : based on first order

# %%
#Mark the ticket of customer:

# %%
df_data_check = (
    df_join_all[(df_join_all['status_id'] == 1) & (df_join_all['time'] > '2022-01-01')][['customer_id', 'ticket_id', 'time', 'type']]
    .sort_values(by=['customer_id','time' ], ascending=True)
)

# %%
df_data_check.head(10)
# Out:
#         customer_id                         ticket_id                    time  \
# 66484        100003  34c4764b4afa000af4c33a525f20eace 2022-05-22 12:52:12.105
# 10001        100004  1c4aa39842bfc83dbb5856c25a33d9cb 2022-12-20 06:26:21.373
# 108794       100007  5565ba5e22475c7cce298a2bea470428 2022-03-21 17:57:18.460
# 0            100009  4f5200dcdcf2396b8d50ff84bf423f32 2022-07-08 17:46:36.145
# 5585         100009  0724203b5146b0ebae6e3678ed7eccde 2022-12-24 09:32:45.477
# 69405        100013  f95441286dcfa045f61a5760662616e1 2022-05-05 12:22:44.587
# 140483       100018  1e40fb2d0f6264ed3127f79b1a12c9c9 2022-09-07 21:13:17.896
# 90595        100018  9a959ff1649950949ff2c0aff4b62205 2022-11-19 16:25:43.981
# 35270        100020  af02fc96a6703af7d93162d9f8c61dba 2022-05-28 19:09:37.936
# 16649        100023  5ed44ff62214268ffcb14d4ea78b04d8 2022-05-16 08:45:42.397
#
#                  type
# 66484   non promotion
# 10001   non promotion
# 108794      promotion
# 0           promotion
# 5585        promotion
# 69405   non promotion
# 140483  non promotion
# 90595       promotion
# 35270       promotion
# 16649       promotion

# %%
df_data_check['row_number'] = df_data_check.groupby('customer_id').cumcount() +1

# %%
# customer have first payment are promotion:
df_data_check[ (df_data_check['type'] == 'promotion') & (df_data_check['row_number'] == 1)]['customer_id'].nunique()
# Out:
# 46189

# %%
46189/47507
# Out:
# 0.9722567200623066

# %%
# More than 97% customer come from promotion => How much retention ?

# %%
df_first_promo_list = df_data_check[ (df_data_check['type'] == 'promotion') & (df_data_check['row_number'] == 1)]['customer_id']
df_first_promo_list.drop_duplicates(inplace = True)

df_first_promo_check = pd.merge(df_data_check, df_first_promo_list, on='customer_id', how='inner')
# Out:
# <ipython-input-179-1cfa51c28d08>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_first_promo_list.drop_duplicates(inplace = True)

# %%
(
df_first_promo_check[(df_first_promo_check['row_number'] == 2)]['customer_id'].nunique()
/
df_first_promo_check['customer_id'].nunique()
)
# Out:
# 0.1308969668102795

# %%
# 13% customer comeback since the promotion
# => Organic group different than promotion ?

# %%
list_first_non_promo = df_data_check[ (df_data_check['type'] == 'non promotion') & (df_data_check['row_number'] == 1)]['customer_id']
list_first_non_promo.drop_duplicates(inplace =True)

df_first_non_promo_check = pd.merge(df_data_check, list_first_non_promo, on='customer_id',how='inner')
(
    df_first_non_promo_check[ (df_first_non_promo_check['row_number'] == 2)]['customer_id'].nunique()
/
    df_first_non_promo_check['customer_id'].nunique()
)
# Out:
# <ipython-input-182-37ef805df965>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   list_first_non_promo.drop_duplicates(inplace =True)
# 0.12195316551641601

# %%
#97% promotion 2022 is for NEW CUSTOMERS
# the retention between organic group is 12%

# %% [markdown]
# ##3.6 Payment success rate

# %% [markdown]
# ###Overview

# %%
def calculate_n_success(x):
  return (x == 1).sum()

df_sr = (
    df_join_all
    .groupby('year_month')
    .agg(n_ords = ('ticket_id', 'count'),
         n_success = ('status_id', calculate_n_success)
    )
    .assign(success_rate=lambda x: (x['n_success'] / x['n_ords']) *100)
)

# %%
df_sr.head(5)
# Out:
#             n_ords  n_success  success_rate
# year_month
# 2019-01       2019       1359     67.310550
# 2019-02       1626       1427     87.761378
# 2019-03       1004        866     86.254980
# 2019-04       4069       3190     78.397641
# 2019-05       4430       3617     81.647856

# %%
from matplotlib.ticker import PercentFormatter

fig, ax1 = plt.subplots(figsize=(15,4))
ax1.bar(df_sr.index, df_sr['n_ords'], color='cornflowerblue')
plt.ylabel('#Tickets', fontsize=11)
plt.xticks(rotation='vertical')

ax2 = ax1.twinx()
ax2.plot(df_sr.index, df_sr['success_rate'], color='tomato', marker='o', ms=3)  # Corrected line
ax2.yaxis.set_major_formatter(PercentFormatter())
plt.ylabel('Success Rate', fontsize=11)
plt.title('Payment Success Rate by month', fontsize=14)
plt.show()

# %% [markdown]
# ### Error trend

# %%
df_join_all.head(5)
# Out:
#                           ticket_id  customer_id paying_method  theater_name  \
# 0  4f5200dcdcf2396b8d50ff84bf423f32       100009  money in app          13.0
# 1  07abbaf28c772692f0367ad992bb3184       100493  bank account         180.0
# 2  1fdbeb7eceba8a27d9d985b5b70c219a       100596  money in app          56.0
# 3  7715c9955866bd296b98543412839abd       100852  bank account         119.0
# 4  776efd7bda0b715084430e6385f67746       100965  money in app         107.0
#
#                       device_number  original_price  discount_value  \
# 0  244764a57dbdeb8fe9b164847ad55183            9.90            2.10
# 1  8fa83cf46284aafd6e5da6c96f7862b5            8.66            1.48
# 2  69cf9244654949047f006e441fa7a8a7           10.31            2.31
# 3  879ed11af9d6d2b5cda4d299590735a7           27.75            1.03
# 4  0a233600d993a02cc1d39fb0d87fc7de            4.33            1.03
#
#    final_price                    time  status_id  campaign_id  \
# 0         7.80 2022-07-08 17:46:36.145          1        83330
# 1         7.18 2022-07-15 20:44:09.952          1        83330
# 2         8.00 2022-07-30 11:16:55.483          1            0
# 3        26.72 2022-07-04 22:33:07.458          1        85940
# 4         3.30 2022-07-03 18:41:45.098          1        85940
#
#                movie_name usergender        dob    campaign_type  \
# 0  Thor: Love And Thunder       Male 1989-02-25  direct discount
# 1  Thor: Love And Thunder       Male 1991-06-09  direct discount
# 2  Thor: Love And Thunder       Male 1989-05-18          unknown
# 3  Thor: Love And Thunder       Male 1997-08-31  direct discount
# 4  Thor: Love And Thunder       Male 1988-09-20  direct discount
#
#         description error_group        model platform  age_days  age  month  \
# 0  Order successful     unknown   iPhone13,1   mobile     13223   36      7
# 1  Order successful     unknown      browser  website     12389   33      7
# 2  Order successful     unknown      unknown   mobile     13141   35      7
# 3  Order successful     unknown  devicemodel   mobile     10114   27      7
# 4  Order successful     unknown  devicemodel   mobile     13381   36      7
#
#    name_day  hour year_month os_version           type
# 0    Friday    17    2022-07        ios      promotion
# 1    Friday    20    2022-07    browser      promotion
# 2  Saturday    11    2022-07    unknown  non promotion
# 3    Monday    22    2022-07    unknown      promotion
# 4    Sunday    18    2022-07    unknown      promotion

# %%
df_error_group = (
    df_join_all[df_join_all['status_id'] != 1]
    .groupby(['year_month', 'error_group'])
    .agg(n_ords = ('ticket_id', 'count'))
    .sort_values(by='year_month', ascending=True)
    .reset_index()
)

# %%
df_error_group.head(5)
# Out:
#   year_month error_group  n_ords
# 0    2019-01    customer     291
# 1    2019-01    external     369
# 2    2019-02    customer      66
# 3    2019-02    external     133
# 4    2019-03    customer      44

# %%
df_error_group['error_group'].unique()
# Out:
# array(['customer', 'external', 'internal'], dtype=object)

# %%
error_color_pairs = [('external','tomato') ,('customer','skyblue'), ('internal','green')]

plt.figure(figsize=(15,4))

for error, color in error_color_pairs:
    df_err_line = df_error_group[df_error_group['error_group'] == error]
    plt.plot(df_err_line['year_month'], df_err_line['n_ords'], label = error, marker='o', color = color, linewidth=2, markersize= 2)

plt.title('Total tickets of error group by months')
plt.xlabel('month')
plt.ylabel('#Tickets')
plt.legend(loc='upper right', bbox_to_anchor=(1.15,1))
plt.xticks(rotation=90)
plt.show()

# %%
# why there are a significant external error in 2022 ?

# %%
df_error = (
    df_join_all[df_join_all['status_id'] != 1]
    .groupby(['year_month', 'description'])
    .agg(n_ords = ('ticket_id', 'count'))
    .sort_values(by='year_month', ascending=True)
    .reset_index()
)

# %%
df_error.head(10)
# Out:
#   year_month                                        description  n_ords
# 0    2019-01  Insufficient funds in customer account. Please...     217
# 1    2019-01                         No response from your bank     228
# 2    2019-01  Password locked due to multiple incorrect atte...      56
# 3    2019-01                           Payment failed from bank     141
# 4    2019-01                                    Payment overdue      18
# 5    2019-02  Insufficient funds in customer account. Please...      42
# 6    2019-02                         No response from your bank      67
# 7    2019-02  Password locked due to multiple incorrect atte...      11
# 8    2019-02                           Payment failed from bank      66
# 9    2019-02                                    Payment overdue      13

# %%
df_error['description'].unique()
# Out:
# array(['Insufficient funds in customer account. Please add more funds and try the transaction again.',
#        'No response from your bank',
#        'Password locked due to multiple incorrect attempts. Choose Forgot Password to unlock.',
#        'Payment failed from bank', 'Payment overdue',
#        'Transaction temporarily limited',
#        'Need verify your account to continue'], dtype=object)

# %%
#Error Distributon
error_color_pairs = [('Insufficient funds in customer account', 'gray'),
        ('Please add more funds and try the transaction again.','tomato'),
       ('No response from your bank','skyblue'),
       ('Password locked due to multiple incorrect attempts. Choose Forgot Password to unlock.', 'green'),
       ('Payment failed from bank','purple'), ('Payment overdue', 'blue'),
       ('Transaction temporarily limited','peru')]

plt.figure(figsize=(15,4))
for error, color in error_color_pairs:
    df_err_line = df_error[df_error['description'] == error]
    plt.plot(df_err_line['year_month'], df_err_line['n_ords'], label = error, marker='o', color = color, linewidth=2, markersize= 2)


plt.title('Total error by months')
plt.xlabel('month')
plt.ylabel('#Tickets')
plt.legend(loc='upper right', bbox_to_anchor=(1.3,1))
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# #### **SR=0%, Why and how?**

# %%
list_sr_0 = list(df_customer_value[df_customer_value['success_rate']<0.1]['customer_id'].unique())

# %%
df_customer_value[df_customer_value['success_rate']<0.1].nunique()
# Out:
# customer_id       13701
# n_total               5
# n_failed              5
# n_success             1
# s_money               1
# s_discount            1
# n_days                1
# n_months              1
# n_promotion           1
# success_rate          1
# promotion_rate        0
# discount_rate         0
# n_order_dis           1
# n_promo_dis           1
# dtype: int64

# %%
df_customer_value.head(5)
# Out:
#    customer_id  n_total  n_failed  n_success  s_money  s_discount  n_days  \
# 0       100001        1         0        1.0     7.42        2.06     1.0
# 1       100003        6         0        6.0    60.95        2.56     6.0
# 2       100004        1         0        1.0    32.25        0.00     1.0
# 3       100005        1         0        1.0     9.49        2.06     1.0
# 4       100006        1         0        1.0    12.37        0.00     1.0
#
#    n_months  n_promotion  success_rate  promotion_rate  discount_rate  \
# 0       1.0          1.0           1.0        1.000000       0.277628
# 1       6.0          1.0           1.0        0.166667       0.042002
# 2       1.0          0.0           1.0        0.000000       0.000000
# 3       1.0          1.0           1.0        1.000000       0.217071
# 4       1.0          0.0           1.0        0.000000       0.000000
#
#   n_order_dis n_promo_dis
# 0         1.0         1.0
# 1         6.0         1.0
# 2         1.0         0.0
# 3         1.0         1.0
# 4         1.0         0.0

# %%
def calculate_n_promotion(x):
  return (x == 'promotion').sum()

df_sr_0_metric = (
    df_join_all[df_join_all['customer_id'].isin(list_sr_0)]
    .groupby('customer_id')
    .agg(
        n_ords=('ticket_id', 'count'),
        n_promotion=('campaign_type', calculate_n_promotion),
        n_discount=('discount_value', 'sum'),
        s_money=('original_price', 'sum')
    )
    .reset_index()
)

df_sr_0_metric['promotion_rate'] = df_sr_0_metric['n_promotion'] / df_sr_0_metric['n_ords']
df_sr_0_metric['discount_rate'] = df_sr_0_metric['n_discount'] / df_sr_0_metric['s_money']

# %%
df_sr_0_metric.iloc[:, 1:].hist(figsize=(12, 8), grid=False, color='cornflowerblue', bins=20)
plt.show()

# %%
from itertools import groupby
#Detail error

df_error_sr_0 = (
    df_join_all[(df_join_all['status_id'] != 1) & (df_join_all['customer_id'].isin(list_sr_0))] # Added a parenthesis here
    .groupby(['year_month', 'description'])
    .agg(n_ords = ('ticket_id', 'count'))
    .sort_values(by='year_month', ascending=True)
    .reset_index()
)

#Error Distributon
error_color_pairs = [('Insufficient funds in customer account', 'gray'),
        ('Please add more funds and try the transaction again.','tomato'),
       ('No response from your bank','skyblue'),
       ('Password locked due to multiple incorrect attempts. Choose Forgot Password to unlock.', 'green'),
       ('Payment failed from bank','purple'), ('Payment overdue', 'blue'),
       ('Transaction temporarily limited','peru')]

plt.figure(figsize=(15,4))
for error, color in error_color_pairs:
    df_err_line = df_error[df_error['description'] == error]
    plt.plot(df_err_line['year_month'], df_err_line['n_ords'], label = error, marker='o', color = color, linewidth=2, markersize= 2)


plt.title('Total error by months')
plt.xlabel('month')
plt.ylabel('#Tickets')
plt.legend(loc='upper right', bbox_to_anchor=(1.3,1))
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# >> - Mostly error because of the bank
# >> - account definition error
